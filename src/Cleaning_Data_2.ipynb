# %%
import pandas as pd
import matplotlib as plt
import seaborn as sns
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
df = pd.read_csv('/content/drive/My Drive/Dataset/data-scrapping-2 (3).csv')

# %%
df.shape
# Out:
# (4290, 12)

# %%
df = df[["title","harga","alamat","lahan parkir","kamar tidur","kamar mandi","jmlh lantai","luas bangunan","luas tanah"]]
df.head(5)
# Out:
#                                                title                 harga  \
# 0  ['Rumah murah dijual BU di peguyangan denpasar...  ['Rp 1.400.000.000']
# 1  ['Jual Rumah Murah Utara Denpasar 400 jutaan B...    ['Rp 475.000.000']
# 2  ['Dijual Rumah Lantai 2 Minimalis Di Denpasar ...  ['Rp 1.600.000.000']
# 3                           ['Rumah baru siap Huni']    ['Rp 925.000.000']
# 4  ['Dijual Rumah Indent Strategis Free Pajak Hrg...  ['Rp 1.200.000.000']
#
#                                               alamat lahan parkir kamar tidur  \
# 0  ['JALAN RAYA PEGUYANGAN DENPASAR PEGUYANGAN KA...        ['2']       ['2']
# 1           ['PENARUNGAN PEGUYANGAN KAJA, DENPASAR']        ['1']       ['2']
# 2                      ['PEGUYANGAN KAJA, DENPASAR']     ['null']       ['4']
# 3                      ['PEGUYANGAN KAJA, DENPASAR']        ['1']       ['3']
# 4                      ['PEGUYANGAN KAJA, DENPASAR']     ['null']       ['3']
#
# ...

# %%
df["title"] = df["title"].str.replace('[','').str.replace("'",'').str.replace(']','')
df["harga"] = df["harga"].str.replace('[','').str.replace("'",'').str.replace(']','')
df["alamat"] = df["alamat"].str.replace('[','').str.replace("'",'').str.replace(']','')
df["lahan parkir"] = df["lahan parkir"].str.replace('[','').str.replace("'",'').str.replace(']','')
df["kamar tidur"] = df["kamar tidur"].str.replace('[','').str.replace("'",'').str.replace(']','')
df["kamar mandi"] = df["kamar mandi"].str.replace('[','').str.replace("'",'').str.replace(']','')
df["jmlh lantai"] = df["jmlh lantai"].str.replace('[','').str.replace("'",'').str.replace(']','')
df["luas bangunan"] = df["luas bangunan"].str.replace('[','').str.replace("'",'').str.replace(']','')
df["luas tanah"] = df["luas tanah"].str.replace('[','').str.replace("'",'').str.replace(']','')
# Out:
# <ipython-input-21-70368307179b>:1: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   df["title"] = df["title"].str.replace('[','').str.replace("'",'').str.replace(']','')
# <ipython-input-21-70368307179b>:2: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   df["harga"] = df["harga"].str.replace('[','').str.replace("'",'').str.replace(']','')
# <ipython-input-21-70368307179b>:3: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   df["alamat"] = df["alamat"].str.replace('[','').str.replace("'",'').str.replace(']','')
# ...

# %%
import numpy as np
for x in range(0 , len(df)):
  for y in range(0,9):
    if df.iloc[x,y] == 'null':
      df.iloc[x,y] = np.NaN

# %%
df.duplicated().sum()
# Out:
# 240

# %%
df.drop_duplicates(inplace = True)
df['title'] = df['title'].str.lower()

# %%
df['harga'] = df['harga'].str.replace('Rp','').str.replace('.','')
# Out:
# <ipython-input-28-0d1f04243e04>:1: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   df['harga'] = df['harga'].str.replace('Rp','').str.replace('.','')

# %%
df.head(5)
# Out:
#                                                title        harga  \
# 0  rumah murah dijual bu di peguyangan denpasar u...   1400000000
# 1  jual rumah murah utara denpasar 400 jutaan bad...    475000000
# 2  dijual rumah lantai 2 minimalis di denpasar utara   1600000000
# 3                               rumah baru siap huni    925000000
# 4  dijual rumah indent strategis free pajak hrg 1...   1200000000
#
#                                               alamat lahan parkir kamar tidur  \
# 0  JALAN RAYA PEGUYANGAN DENPASAR PEGUYANGAN KAJA...            2           2
# 1               PENARUNGAN PEGUYANGAN KAJA, DENPASAR            1           2
# 2                          PEGUYANGAN KAJA, DENPASAR          NaN           4
# 3                          PEGUYANGAN KAJA, DENPASAR            1           3
# 4                          PEGUYANGAN KAJA, DENPASAR          NaN           3
#
#   kamar mandi jmlh lantai luas bangunan luas tanah
# ...

# %%
df.isna().sum()
# Out:
# title               0
# harga               0
# alamat              0
# lahan parkir     1322
# kamar tidur         0
# kamar mandi         1
# jmlh lantai      2090
# luas bangunan      20
# luas tanah          2
# dtype: int64

# %%
df[df['luas tanah'].values < 10]
df.loc[710 , 'luas tanah'] = 100
df.loc[1178 , 'luas tanah'] = 2000

# %%
df[df['luas bangunan'].values < 10]
df.loc[960 , 'luas bangunan'] = 100
df.loc[1018 , 'luas bangunan'] = 100
df.loc[1745 , 'luas bangunan'] = 100
df.loc[2279 , 'luas bangunan'] = 200
df.loc[2339 , 'luas bangunan'] = 100
df.loc[2347 , 'luas bangunan'] = 50
df.loc[3063 , 'luas bangunan'] = 100
df.loc[3940 , 'luas bangunan'] = 100

# %%
df[df['luas tanah'].values <= 20]
# df.loc[716 , 'luas tanah'] = 100
df.loc[1872 , 'luas tanah'] = 1500
#df.loc[2097 , 'luas bangunan'] = 100

# %%
df.drop(index=1844,inplace=True)
#df.loc[1844]

# %%
df.duplicated().sum()
# Out:
# 55

# %%
# menampilkan data duplikat berdasarkan semua kolom
#df[df.duplicated()]
#df.drop_duplicates(inplace=True)
#df[df.duplicated(['title'])]
# menampilkan data duplikat berdasarkan kolom tertentu
# print(df[df.duplicated(['Nama', 'Umur'])])
# Pada contoh di atas, df.duplicated() akan mengem

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df[df['luas bangunan'].isna() == True]
df.loc[1407 , 'luas bangunan'] = 50
df.loc[1407 , 'lahan parkir'] = 3
df.loc[1912	 , 'luas bangunan'] = 40
df.loc[1912 , 'lahan parkir'] = 2
# Out:
# Empty DataFrame
# Columns: [title, alamat, lahan parkir, kamar tidur, kamar mandi, luas bangunan, luas tanah, jmlh lantai, harga, tile, cek rumah, kos]
# Index: []

# %%
df[df['luas tanah'].isna() == True]
df.loc[710 , 'luas tanah'] = 100
df.loc[1178 , 'luas tanah'] = 2000
# Out:
#                                                   title  \
# 164   dijual cepat rumah baru siap huni model minima...
# 1227  jual bangunan rumah kayu knockdown 5x10m model...
# 1322           rumah asri view sawah 20 mnt dari canggu
# 1351  rumah mewah siap huni di delod puri kediri tab...
# 1427  gria trisna asri pandak bandung di jual rumah ...
# 1456  dijual rumah milenial terbaru lokasi di batuaj...
# 2239  rumah baru harga 1,1 m nego dikit lokasi :bela...
# 2381           rumah di jl singasari lumintang denpasar
# 3788       rumah indent di kusuma bangsa denpasar barat
#
#                                                  alamat  lahan parkir  \
# 164                                  BATUBULAN, GIANYAR           NaN
# 1227  JALAN RAYA SEMANA MAMBAL, BADUNG BALI MAMBAL, ...           NaN
# 1322    LESTARI NYITDAH RESIDENCE NO 12 KEDIRI, TABANAN           NaN
# 1351                                    KEDIRI, TABANAN           NaN
# ...

# %%
#print(df.loc[10, 'title'])   # Jakarta
print(df.loc[60, 'title':'alamat'])

# menggunakan iloc untuk mengambil data berdasarkan indeks numerik
#print(df.iloc[20, 0])   # Jakarta
print(df.iloc[60, 0:1])
# Out:
# title     rumah dijual seperti villa siap huni view sawa...
# alamat                                     KERAMAS, GIANYAR
# Name: 60, dtype: object
# title    2 unit terakhir...rumah terlaris di bali
# Name: 62, dtype: object

# %%
df.iloc[66]
# Out:
# title            rumah sitaan murah batubulan
# alamat                     BATUBULAN, GIANYAR
# lahan parkir                              NaN
# kamar tidur                               2.0
# kamar mandi                               1.0
# luas bangunan                           100.0
# luas tanah                              104.0
# jmlh lantai                               1.0
# harga                             530000000.0
# tile             rumah sitaan murah batubulan
# cek rumah        rumah sitaan murah batubulan
# kos                                       NaN
# Name: 69, dtype: object

# %%
df.loc[66]
# Out:
# title            sale rumah cantik minimalis lingk perum guwang...
# alamat           JALAN RAYA GUWANG & JALAN RAYA CELUK-SUKAWATI ...
# lahan parkir                                                  10.0
# kamar tidur                                                    2.0
# kamar mandi                                                    1.0
# luas bangunan                                                 36.0
# luas tanah                                                    87.0
# jmlh lantai                                                    1.0
# harga                                                  445000000.0
# tile             sale rumah cantik minimalis lingk perum guwang...
# cek rumah        sale rumah cantik minimalis lingk perum guwang...
# kos                                                            NaN
# Name: 66, dtype: object

# %%
df.to_csv('clean_rumah_terbaru1.csv' , index=False)

# %%
df = pd.read_csv('/content/drive/My Drive/Dataset/clean_rumah_terbaru1.csv')
df.head(5)
# Out:
#                                                title  \
# 0  rumah minimalis murah lokasi strategis karangasem
# 1  rumah minimalis murah lokasi strategis karangasem
# 2           rumah subsidi dekat kota karangasem bali
# 3       rumah semi finishing padang kerta karangasem
# 4                        jual tanah bonus rumah lama
#
#                      alamat  lahan parkir  kamar tidur  kamar mandi  \
# 0                KARANGASEM           NaN          2.0          1.0
# 1   KARANG ASEM, KARANGASEM           NaN          2.0          1.0
# 2   KARANG ASEM, KARANGASEM           NaN          2.0          1.0
# 3  PADANG KERTA, KARANGASEM           NaN          2.0          1.0
# 4       SUBAGAN, KARANGASEM           NaN          1.0          1.0
#
#    luas bangunan  luas tanah  jmlh lantai        harga  \
# 0           36.0       100.0          1.0  250000000.0
# 1           36.0       100.0          1.0  250000000.0
# 2           30.0        60.0          1.0  178000000.0
# ...

# %%
df = pd.read_csb

# %%
for x in range(0,len(df)):
    if df.iloc[x,7] == 1:
        if  (('second' in str(df.iloc[x,0])) and  ('lt' in str(df.iloc[x,0]))) or (('lantai' in str(df.iloc[x,0])) and ('2' in str(df.iloc[x,0]))) or (('lantai' in str(df.iloc[x,0])) and ('dua' in str(df.iloc[x,0]))) or (('lt' in str(df.iloc[x,0])) and ('2' in str(df.iloc[x,0]))) or (('lt' in str(df.iloc[x,0])) and ('dua' in str(df.iloc[x,0]))):
            #(('second' in str(df.iloc[x,0])) &  ('lt' in str(df.iloc[x,0]))) or (('lantai' in str(df.iloc[x,0])) and ('2' in str(df.iloc[x,0]))) or (('lantai' in str(df.iloc[x,0])) and ('dua' in str(df.iloc[x,0]))) or (('lt' in str(df.iloc[x,0])) and ('2' in str(df.iloc[x,0]))) or (('lt' in str(df.iloc[x,0])) and ('dua' in str(df.iloc[x,0]))):
            df.loc[x,'jmlh lantai'] = 2
        elif (('three' in str(df.iloc[x,0])) and  ('lt' in str(df.iloc[x,0]))) or (('lantai' in str(df.iloc[x,0])) and ('3' in str(df.iloc[x,0]))) or (('lantai' in str(df.iloc[x,0])) and ('tiga' in str(df.iloc[x,0]))) or (('lt' in str(df.iloc[x,0])) and ('3' in str(df.iloc[x,0]))) or (('lt' in str(df.iloc[x,0])) and ('tiga' in str(df.iloc[x,0]))):
            df.loc[x,'jmlh lantai'] = 3
        else:
            df.loc[x,'jmlh lantai'] = 1
    else:
        df.loc[x,'jmlh lantai'] =  df.iloc[x,7]

# %%
df[df['luas tanah'].isna() ==True]
df.loc[160 , 'luas tanah'] = 100
df.loc[160 , 'lahan parkir'] = 2

df.loc[1209 , 'luas tanah'] = 100
df.loc[1209 , 'lahan parkir'] = 2

df.loc[1304 , 'luas tanah'] = 70
df.loc[1304 , 'lahan parkir'] = 2

df.loc[1333 , 'luas tanah'] = 70
df.loc[1333 , 'lahan parkir'] = 2

df.loc[1409 , 'luas tanah'] = 100
df.loc[1409 , 'lahan parkir'] = 2

df.loc[1438 , 'luas tanah'] = 62
df.loc[1438 , 'lahan parkir'] = 2

df.loc[2187 , 'luas tanah'] = 90
df.loc[2187 , 'lahan parkir'] = 2

df.loc[2329 , 'luas tanah'] = 160
df.loc[2329 , 'lahan parkir'] = 2

df.loc[3732 , 'luas tanah'] = 75
df.loc[3732 , 'lahan parkir'] = 2
df.loc[3732 , 'jmlh lantai'] = 2

# %%
#df[(df['harga'].isna() == True) & (df['luas tanah'].values >= 200) & (df['luas tanah'].values <= 300)]
df.loc[235 , 'harga'] = 1838797000
df.loc[1050 , 'harga'] = 1838797000
df.loc[2684 , 'harga'] =1838797000
#df.loc[(df["harga"].isna() == True) & (df['luas tanah'].values <= 200) , 'harga'] = 1658838000
#df[(df['harga'].isna() == True)]

# %%
df.loc[235]
# Out:
# title            rumah lantai 1 dikawasan batubulan gianyar bali
# alamat                                         SUKAWATI, GIANYAR
# lahan parkir                                                 NaN
# kamar tidur                                                  3.0
# kamar mandi                                                  2.0
# luas bangunan                                               85.0
# luas tanah                                                 100.0
# jmlh lantai                                                  1.0
# harga                                               1838797000.0
# tile             rumah lantai 1 dikawasan batubulan gianyar bali
# cek rumah        rumah lantai 1 dikawasan batubulan gianyar bali
# kos                                                          NaN
# Name: 235, dtype: object

# %%
#df[(df['harga'].isna() == False) & ((df['luas tanah'].values >= 200)& (df['luas tanah'].values <= 200)) & ((df['luas bangunan'].values <= 200)& (df['luas bangunan'].values >= 130)) & ((df['kamar tidur'].values <= 4)& (df['kamar mandi'].values <= 3))].mean()
df.loc[(df["harga"].isna() == False) & (df["harga"].values == 1658838000) ]
# Out:
#                                                   title  \
# 209    rumah gianyar abianbase 200m2 land 3 kamar tidur
# 236   rumah modern style villa dekat baypass ida bag...
# 1188     rumah abianbase badung 2 kamar tidur siap huni
# 2300  rumah denpasar jl buluh indah 3 kamar tidur si...
# 2835  rumah 3 kamar tidur sanur view sawah dekat pantai
# 3070  rumah mewah gatsu tengah 980m2 land with priva...
# 3510  rumah ayani denpasar minimalis modern 4 kamar ...
# 3521  rumah cantik dan luas area tukad badung, renon...
# 4069  rumah modern siap huni hanya 150 mtr dari jln ...
#
#                           alamat  lahan parkir  kamar tidur  kamar mandi  \
# 209             GIANYAR, GIANYAR           NaN          3.0          1.0
# 236             GIANYAR, GIANYAR           NaN          4.0          4.0
# 1188              MENGWI, BADUNG           NaN          2.0          1.0
# 2300    DENPASAR BARAT, DENPASAR           NaN          3.0          3.0
# ...

# %%
# 3070 #13139710000
# 3521 #4387162000
df.loc[3070 , 'harga'] = 13139710000
df.loc[3521 , 'harga'] = 4387162000

# %%
df[df['lahan parkir'] >= 1000]
df.loc[149 , 'lahan parkir'] = 8
df.loc[546 , 'lahan parkir'] = 3
df.loc[1965 , 'lahan parkir'] = 4
df.loc[1985 , 'lahan parkir'] = 10
df.loc[2603 , 'lahan parkir'] = 60
df.loc[2745 , 'lahan parkir'] = 4
df.loc[755 , 'lahan parkir'] = 3
df.loc[3075 , 'lahan parkir'] = 5
df.loc[3126 , 'lahan parkir'] = 15
df.loc[3201 , 'lahan parkir'] = 15
df.loc[3241 , 'lahan parkir'] = 5
df.loc[3534 , 'lahan parkir'] = 8
df.loc[1965 , 'lahan parkir'] = 4
df.loc[1985 , 'lahan parkir'] = 10
df.loc[2603 , 'lahan parkir'] = 60
df.loc[2745 , 'lahan parkir'] = 4
# Out:
#                                                   title  \
# 755                       jual rumah kost 20 kamar bali
# 953                  rumah semi villa di terrace mumbul
# 1130                                  rumah taman griya
# 1579       dijual kost + rumah modern di kediri tabanan
# 1864  bak raja rumah style bali zaman kerajaan puri ...
# 2203               dijual rumah baru dan murah di renon
# 2235                        rumah minimalis di antasura
# 2685                      rumah di tunggak bingin sanur
# 2792                             dijual rumah baru gres
# 3413                    dijual rumah minimalis lantai 2
# 3575                      rumah mewah di renon denpasar
# 3657              dijual rumah view sawah kota denpasar
# 3684                         dijual rumah baru lantai 1
# 3763            dijual rumah lantai 1 murah di denpasar
# 3804  rumah style villa di sanur penyaringan denpasa...
# 3910                                   rumah style bali
#
# ...

# %%
df[df['lahan parkir'] >= 500]
df.loc[3910 , 'lahan parkir'] = 10
df.loc[3804 , 'lahan parkir'] = 25
df.loc[3763 , 'lahan parkir'] = 8
df.loc[3684 , 'lahan parkir'] = 10
df.loc[3657 , 'lahan parkir'] = 8
df.loc[3575 , 'lahan parkir'] = 6
df.loc[3413 , 'lahan parkir'] = 4
df.loc[2792 , 'lahan parkir'] = 6
df.loc[2685 , 'lahan parkir'] = 4
df.loc[2235 , 'lahan parkir'] = 8

df.loc[2203 , 'lahan parkir'] = 4
df.loc[1864 , 'lahan parkir'] = 70
df.loc[1130 , 'lahan parkir'] = 4
df.loc[953 , 'lahan parkir'] = 5
# Out:
#                                              title           alamat  \
# 755                  jual rumah kost 20 kamar bali   CANGGU, BADUNG
# 1579  dijual kost + rumah modern di kediri tabanan  KEDIRI, TABANAN
#
#       lahan parkir  kamar tidur  kamar mandi  luas bangunan  luas tanah  \
# 755         1500.0         20.0         20.0          450.0       280.0
# 1579        1000.0         17.0         16.0          300.0       500.0
#
#       jmlh lantai         harga                                          tile  \
# 755           3.0  2.850000e+09                 jual rumah kost 20 kamar bali
# 1579          1.0  4.000000e+09  dijual kost + rumah modern di kediri tabanan
#
#                                          cek rumah  \
# 755                  jual rumah kost 20 kamar bali
# 1579  dijual kost + rumah modern di kediri tabanan
#
#                                                kos
# 755                  jual rumah kost 20 kamar bali
# ...

# %%
# # df.to_csv('data_clean2.csv')
# df = pd.read_csv('/content/drive/My Drive/Dataset/data_clean2.csv')
# df.head(5)
#data_clean2

# %%
#df[(df['lahan parkir'] >= 100) & (df['lahan parkir'] <= 500)]
for x in range(0,len(df)):
  # if pd.isna(df.iloc[x,3]):
  if (df.iloc[x,6] >= df.iloc[x,7]) & (df.iloc[x,3] >= 20 ) :
     #y = int((df.iloc[x,7]) - (df.iloc[x,6]))
     df.loc[x,'lahan parkir'] = 5
    #  if y > 55 :
    #    df.loc[x,'lahan parkir'] = 60
    #  elif (y >= 45 and y <=55):
    #    df.loc[x,'lahan parkir'] = 10
    #  elif y < 45 & y > 30:
    #    df.loc[x,'lahan parkir'] = 8
    #  elif y <= 30 & y >= 20:
    #    df.loc[x,'lahan parkir'] = 6
    #  elif y < 20 :
    #     df.loc[x,'lahan parkir'] = 4
    #  else:
    #    df.loc[x,'lahan parkir'] = 4

# %%
df.isna().sum()
# Out:
# Unnamed: 0          0
# title               0
# alamat              0
# lahan parkir        0
# kamar tidur         0
# kamar mandi         0
# luas bangunan       0
# luas tanah          0
# jmlh lantai         0
# harga               0
# tile                0
# cek rumah           0
# kos              4024
# dtype: int64

# %%
df = df[['title','alamat','lahan parkir' , 'kamar tidur' , 'kamar mandi' , 'luas bangunan' , 'luas tanah' , 'jmlh lantai' , 'harga']]

# %%
df['lahan parkir'].unique()
df['lahan parkir'].astype(int)
# Out:
# 0       60
# 1       60
# 2        6
# 3       60
# 4       60
#         ..
# 4134    10
# 4135     4
# 4136     4
# 4137    10
# 4138    20
# Name: lahan parkir, Length: 4139, dtype: int64

# %%
df.dtypes
# Out:
# title             object
# alamat            object
# lahan parkir     float64
# kamar tidur      float64
# kamar mandi      float64
# luas bangunan    float64
# luas tanah       float64
# jmlh lantai      float64
# harga            float64
# dtype: object

# %%
df[(df['lahan parkir'] >= 100) & (df['lahan parkir'] <= 500)]
# Out:
#                                                   title  \
# 46                 rumah dengan 3 kamar tidur siap huni
# 59    dijual cepat rumah kost termurah dekat denpasa...
# 94                             rumah 2 kamar di ketewel
# 97                                rumah cantik sukawati
# 300                rumah di bypass gianyar dekat pantai
# 349                                rumah cantik gianyar
# 381                     rumah 3 kamar di pering gianyar
# 382                               rumah modern lantai 1
# 463   dijual rumah kost termurah 10 kamar tidur lega...
# 710   hunian rumah inimalis 2 lantai di canggu-bali ...
# 768   rumah di kuta palace residence badung denpasar...
# 991   rumah 3 lantai view laut di ungasan dekat nirm...
# 1003                    rumah murah strategis di canggu
# 1039                               rumah elite jimbaran
# 1247             dijual rumah baru minimalis semi villa
# 1308  rumah dekat pantai bali canggu bisa kpr dp bis...
# ...

# %%
df.isna().sum()
# Out:
# title               0
# alamat              0
# lahan parkir     2442
# kamar tidur         0
# kamar mandi         0
# luas bangunan       0
# luas tanah          0
# jmlh lantai         0
# harga               0
# tile                0
# cek rumah           0
# kos              4024
# dtype: int64

# %%
df[(df['harga'].isna() == False) & ((df['luas tanah'].values >= 400)& (df['luas tanah'].values <=450)) & ((df['luas bangunan'].values >= 400)& (df['luas bangunan'].values <= 420))  & ((df['kamar tidur'].values <= 5) & (df['kamar mandi'].values <= 5))].mean()
# Out:
# <ipython-input-172-90d2035e428a>:1: FutureWarning: The default value of numeric_only in DataFrame.mean is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df[(df['harga'].isna() == False) & ((df['luas tanah'].values >= 400)& (df['luas tanah'].values <=450)) & ((df['luas bangunan'].values >= 400)& (df['luas bangunan'].values <= 420))  & ((df['kamar tidur'].values <= 5) & (df['kamar mandi'].values <= 5))].mean()
# lahan parkir     1.200000e+01
# kamar tidur      4.500000e+00
# kamar mandi      4.166667e+00
# luas bangunan    4.060000e+02
# luas tanah       4.163333e+02
# jmlh lantai      1.166667e+00
# harga            4.550000e+09
# kos                       NaN
# dtype: float64

# %%
#menampilkan data yang mengandung kata kos
x=0
for x in range(0, len(df)):
  if (('kos' in str(df.iloc[x,0]))) :
      print(df.iloc[x,0])

# %%
df = df.drop(df[(df['kamar tidur'] >= 10) & (df['kamar mandi'].values >= 9)].index)

# %%
df[(df['kamar tidur'].values >= 5)]
# Out:
#                                                   title  \
# 27                                  rumah villa di jual
# 53    dijual cepat rumah tinggal view bandara dan to...
# 59    dijual cepat rumah kost termurah dekat denpasa...
# 74                           rumah style bali lengkap..
# 97                                rumah cantik sukawati
# ...                                                 ...
# 4094  rumah jual di area teuku umar, denpasar, dekat...
# 4104  dijual rumah 2 lantai di jln utama puputan ren...
# 4112                            rumah lantai 2 di renon
# 4118  rumah style villa mewah lingkungan elite di te...
# 4121                               rumah di teras ayung
#
#                                     alamat  lahan parkir  kamar tidur  \
# 27                           SABA, GIANYAR          60.0          9.0
# 53                        GIANYAR, GIANYAR           8.0          6.0
# 59             BATUBULAN SUKAWATI, GIANYAR           8.0          9.0
# ...

# %%
#Data dengan iloc yang mengandung kata kos
df.drop(3331 , inplace=True)
df.drop(3342 , inplace=True)
df.drop(3774 , inplace=True)
df.drop(3812 , inplace=True)
df.drop(4043 , inplace=True)
df.drop(4017 , inplace=True)
df.drop(3948 , inplace=True)
df.drop(3948 , inplace=True)
df.drop(2969 , inplace=True)
df.drop(2837 , inplace=True)
df.drop(2624 , inplace=True)
df.drop(1404 , inplace=True)
df.drop(1278 , inplace=True)
df.drop(865 , inplace=True)
df.drop(612 , inplace=True)
df.drop(310 , inplace=True)
df.drop(299 , inplace=True)
df.drop(3119 , inplace=True)
df.drop(3148 , inplace=True)
df.drop(3143 , inplace=True)
df.drop(3444 , inplace=True)

# %%
df[df['kamar tidur']>=15]
# Out:
#                                                  title             alamat  \
# 1144  rumah murah di banjar semer kerobokan (dwjker18)  KEROBOKAN, BADUNG
#
#       lahan parkir  kamar tidur  kamar mandi  luas bangunan  luas tanah  \
# 1144          20.0         34.0          3.0          100.0       185.0
#
#       jmlh lantai         harga
# 1144          1.0  1.890000e+09

# %%
df.drop(1144 , inplace=True)

# %%
df.to_csv('rumah_clean6_real_rumah.csv', index=False)

# %% [markdown]
# # Cleaning Data ke 3

# %%
import pandas as pd

# %%
df = pd.read_csv('/content/drive/My Drive/Dataset/data-scrapping-2 (2).csv')
df.head(5)
# Out:
#                                            data-href  \
# 0    https://www.lamudi.co.id/dijual-rumah-bu-3.html
# 1  https://www.lamudi.co.id/rumah-cantik-dijual-1...
# 2  https://www.lamudi.co.id/rumah-murah-luas-127m...
# 3  https://www.lamudi.co.id/rumah-dengan-harga-mu...
# 4  https://www.lamudi.co.id/rumah-baru-kecil-jln-...
#
#                                             title                 harga  \
# 0     ['Dijual rumah BU di tengah kota denpasar']    ['Rp 650.000.000']
# 1                         ['Rumah Cantik Dijual']  ['Rp 1.300.000.000']
# 2     ['Rumah Murah Luas 127m² di Dalung Permai']  ['Rp 1.000.000.000']
# 3     ['Rumah dengan harga Murah di Dalung Bali']    ['Rp 850.000.000']
# 4  ['Rumah Baru KeciL Jln 5mtr di DALUNG PERMAI']    ['Rp 475.000.000']
#
#                         alamat lahan parkir   listrik kamar tidur kamar mandi  \
# 0  ['DALUNG PERMAI, DENPASAR']     ['null']  ['null']       ['2']       ['1']
# ...

# %%
df = df[["title","harga","alamat","lahan parkir","kamar tidur","kamar mandi","jmlh lantai","luas bangunan","luas tanah"]]
df.head(5)
# Out:
#                                             title                 harga  \
# 0     ['Dijual rumah BU di tengah kota denpasar']    ['Rp 650.000.000']
# 1                         ['Rumah Cantik Dijual']  ['Rp 1.300.000.000']
# 2     ['Rumah Murah Luas 127m² di Dalung Permai']  ['Rp 1.000.000.000']
# 3     ['Rumah dengan harga Murah di Dalung Bali']    ['Rp 850.000.000']
# 4  ['Rumah Baru KeciL Jln 5mtr di DALUNG PERMAI']    ['Rp 475.000.000']
#
#                         alamat lahan parkir kamar tidur kamar mandi  \
# 0  ['DALUNG PERMAI, DENPASAR']     ['null']       ['2']       ['1']
# 1  ['DALUNG PERMAI, DENPASAR']     ['null']       ['3']       ['3']
# 2  ['DALUNG PERMAI, DENPASAR']     ['null']       ['3']       ['2']
# 3  ['DALUNG PERMAI, DENPASAR']        ['1']       ['4']       ['3']
# 4  ['DALUNG PERMAI, DENPASAR']     ['null']       ['2']       ['2']
#
#   jmlh lantai luas bangunan luas tanah
# 0    ['null']        ['80']    ['100']
# 1    ['null']       ['100']    ['150']
# ...

# %%
df["title"] = df["title"].str.replace('[','').str.replace("'",'').str.replace(']','')
# Out:
# <ipython-input-8-83a2e20988f1>:1: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   df["title"] = df["title"].str.replace('[','').str.replace("'",'').str.replace(']','')

# %%
df["harga"] = df["harga"].str.replace('[','').str.replace("'",'').str.replace(']','')
df["alamat"] = df["alamat"].str.replace('[','').str.replace("'",'').str.replace(']','')
df["lahan parkir"] = df["lahan parkir"].str.replace('[','').str.replace("'",'').str.replace(']','')
df["kamar tidur"] = df["kamar tidur"].str.replace('[','').str.replace("'",'').str.replace(']','')
df["kamar mandi"] = df["kamar mandi"].str.replace('[','').str.replace("'",'').str.replace(']','')
df["jmlh lantai"] = df["jmlh lantai"].str.replace('[','').str.replace("'",'').str.replace(']','')
df["luas bangunan"] = df["luas bangunan"].str.replace('[','').str.replace("'",'').str.replace(']','')
df["luas tanah"] = df["luas tanah"].str.replace('[','').str.replace("'",'').str.replace(']','')
# Out:
# <ipython-input-9-9755b936d245>:1: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   df["harga"] = df["harga"].str.replace('[','').str.replace("'",'').str.replace(']','')
# <ipython-input-9-9755b936d245>:2: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   df["alamat"] = df["alamat"].str.replace('[','').str.replace("'",'').str.replace(']','')
# <ipython-input-9-9755b936d245>:3: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   df["lahan parkir"] = df["lahan parkir"].str.replace('[','').str.replace("'",'').str.replace(']','')
# ...

# %%
df
# Out:
#                                         title             harga  \
# 0     Dijual rumah BU di tengah kota denpasar    Rp 650.000.000
# 1     Dijual rumah BU di tengah kota denpasar  Rp 1.300.000.000
# 2     Dijual rumah BU di tengah kota denpasar  Rp 1.000.000.000
# 3     Dijual rumah BU di tengah kota denpasar    Rp 850.000.000
# 4     Dijual rumah BU di tengah kota denpasar    Rp 475.000.000
# ...                                       ...               ...
# 4285  Dijual rumah BU di tengah kota denpasar  Rp 3.500.000.000
# 4286  Dijual rumah BU di tengah kota denpasar  Rp 1.300.000.000
# 4287  Dijual rumah BU di tengah kota denpasar    Rp 875.000.000
# 4288  Dijual rumah BU di tengah kota denpasar  Rp 1.350.000.000
# 4289  Dijual rumah BU di tengah kota denpasar    Rp 950.000.000
#
#                                    alamat lahan parkir kamar tidur  \
# 0                 DALUNG PERMAI, DENPASAR         null           2
# ...

# %%
import numpy as np

# %%
for x in range(0 , len(df)):
  for y in range(0,9):
    if df.iloc[x,y] == 'null':
      df.iloc[x,y] = np.NaN

# %%
df.duplicated().sum()
# Out:
# 399

# %%
df.drop_duplicates(inplace = True)

# %%
df.shape
# Out:
# (3891, 9)

# %%
x = df[df['title'].values == 'Dijual rumah BU di tengah kota denpasar' ]
len(x)
# Out:
# 1

# %%
df.isna().sum()
# Out:
# title               0
# harga              26
# alamat              0
# lahan parkir     2723
# kamar tidur         1
# kamar mandi         2
# jmlh lantai      3534
# luas bangunan      25
# luas tanah          1
# dtype: int64

# %%
df.head(5)
# Out:
#                                         title             harga  \
# 0     Dijual rumah BU di tengah kota denpasar    Rp 650.000.000
# 1                         Rumah Cantik Dijual  Rp 1.300.000.000
# 2     Rumah Murah Luas 127m² di Dalung Permai  Rp 1.000.000.000
# 3     Rumah dengan harga Murah di Dalung Bali    Rp 850.000.000
# 4  Rumah Baru KeciL Jln 5mtr di DALUNG PERMAI    Rp 475.000.000
#
#                     alamat  lahan parkir  kamar tidur  kamar mandi  \
# 0  DALUNG PERMAI, DENPASAR           NaN          2.0          1.0
# 1  DALUNG PERMAI, DENPASAR           NaN          3.0          3.0
# 2  DALUNG PERMAI, DENPASAR           NaN          3.0          2.0
# 3  DALUNG PERMAI, DENPASAR           1.0          4.0          3.0
# 4  DALUNG PERMAI, DENPASAR           NaN          2.0          2.0
#
#    jmlh lantai  luas bangunan  luas tanah
# 0          NaN           80.0       100.0
# 1          NaN          100.0       150.0
# 2          NaN           70.0       127.0
# ...

# %%
#memberikan nila jumlah lantai yang kosong =1
for x in range(0,len(df)):
  if pd.isna(df.iloc[x,6]) == True:
    df.iloc[x,6] = 1

# %%
# df.duplicated().sum()
df.iloc[2,6] =1

# %%
df.isna().sum()
# Out:
# title               0
# harga              26
# alamat              0
# lahan parkir     2723
# kamar tidur         1
# kamar mandi         2
# jmlh lantai         0
# luas bangunan      25
# luas tanah          1
# dtype: int64

# %%
df['title'] = df['title'].str.lower()

# %%
#perbaiki data jumlah lantai , jika terdapat 2 atau 3 dengan kata lt atau lantai maka
for x in range(0,len(df)):
    if df.iloc[x,6] == 1:
        if  (('second' in str(df.iloc[x,0])) and  ('lt' in str(df.iloc[x,0]))) or (('lantai' in str(df.iloc[x,0])) and ('2' in str(df.iloc[x,0]))) or (('lantai' in str(df.iloc[x,0])) and ('dua' in str(df.iloc[x,0]))) or (('lt' in str(df.iloc[x,0])) and ('2' in str(df.iloc[x,0]))) or (('lt' in str(df.iloc[x,0])) and ('dua' in str(df.iloc[x,0]))):
            #(('second' in str(df.iloc[x,0])) &  ('lt' in str(df.iloc[x,0]))) or (('lantai' in str(df.iloc[x,0])) and ('2' in str(df.iloc[x,0]))) or (('lantai' in str(df.iloc[x,0])) and ('dua' in str(df.iloc[x,0]))) or (('lt' in str(df.iloc[x,0])) and ('2' in str(df.iloc[x,0]))) or (('lt' in str(df.iloc[x,0])) and ('dua' in str(df.iloc[x,0]))):
            df.iloc[x,6] = 2
        elif (('three' in str(df.iloc[x,0])) and  ('lt' in str(df.iloc[x,0]))) or (('lantai' in str(df.iloc[x,0])) and ('3' in str(df.iloc[x,0]))) or (('lantai' in str(df.iloc[x,0])) and ('tiga' in str(df.iloc[x,0]))) or (('lt' in str(df.iloc[x,0])) and ('3' in str(df.iloc[x,0]))) or (('lt' in str(df.iloc[x,0])) and ('tiga' in str(df.iloc[x,0]))):
            df.iloc[x,6] = 3
        else:
            df.iloc[x,6] = 1
    else:
        df.iloc[x,6] =  df.iloc[x,6]

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df['harga'] = df['harga'].str.replace('Rp','')

# %%
df['harga'] = df['harga'].str.replace('.','').str.replace(',','')
# Out:
# <ipython-input-12-8c0fb06b5666>:1: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   df['harga'] = df['harga'].str.replace('.','').str.replace(',','')

# %%
df[(df['luas bangunan'].values > df['luas tanah'].values) & (df['jmlh lantai'].values == 1) & (df['luas bangunan'].values > 1000)]
# Out:
#                                                   title         harga  \
# 81      rumah di pinggir jalan setia budi denpasar bali   17000000000
# 541   rumah modern minimalis tenang nyaman mahendrad...    2000000000
# 961       dijual rumah di denpasar barat padang sambian    3250000000
# 3286                rumah vila style padang sambian(22)    4500000000
#
#                                                  alamat  lahan parkir  \
# 81    JALAN SETIABUDI, DENPASAR, INDONESIA DENPASAR ...           6.0
# 541   JALAN MAHENDRADATTA PADANGSAMBIAN DENPASAR BAR...           NaN
# 961   JL PADANGSAMBIAN DENPASAR DENPASAR BARAT, DENP...           1.0
# 3286                      PADANG SAMBIAN KAJA, DENPASAR           2.0
#
#       kamar tidur  kamar mandi  jmlh lantai  luas bangunan  luas tanah
# 81            8.0          3.0          1.0        10000.0      1400.0
# 541           3.0          3.0          1.0         3210.0       121.0
# ...

# %%
df[(df['luas bangunan'].values > df['luas tanah'].values) & (df['jmlh lantai'].values == 1) & (df['luas bangunan'].values > 500)]
# Out:
#                                                   title         harga  \
# 81      rumah di pinggir jalan setia budi denpasar bali   17000000000
# 541   rumah modern minimalis tenang nyaman mahendrad...    2000000000
# 721          rumah mewah style modern dekat ke seminyak           NaN
# 961       dijual rumah di denpasar barat padang sambian    3250000000
# 3038                  rumah sunset road kuta bonus toko    7500000000
# 3286                rumah vila style padang sambian(22)    4500000000
# 3334         rumah mewah di athena seminyak badung bali   12000000000
#
#                                                  alamat  lahan parkir  \
# 81    JALAN SETIABUDI, DENPASAR, INDONESIA DENPASAR ...           6.0
# 541   JALAN MAHENDRADATTA PADANGSAMBIAN DENPASAR BAR...           NaN
# 721                            DENPASAR BARAT, DENPASAR           NaN
# 961   JL PADANGSAMBIAN DENPASAR DENPASAR BARAT, DENP...           1.0
# ...

# %%
for x in range(0,len(df)):
    if df.iloc[x,6] == 1:
        if (df.iloc[x,7] > df.iloc[x,8]) and (df.iloc[x,7] < 1000):
            df.iloc[x,6] = 2
        else:
          df.iloc[x,6] = df.iloc[x,6]

# %%
df[(df['luas bangunan'].values > df['luas tanah'].values) & (df['jmlh lantai'].values == 1)]
# Out:
#                                                  title         harga  \
# 81     rumah di pinggir jalan setia budi denpasar bali   17000000000
# 541  rumah modern minimalis tenang nyaman mahendrad...    2000000000
# 721         rumah mewah style modern dekat ke seminyak           NaN
# 961      dijual rumah di denpasar barat padang sambian    3250000000
#
#                                                 alamat  lahan parkir  \
# 81   JALAN SETIABUDI, DENPASAR, INDONESIA DENPASAR ...           6.0
# 541  JALAN MAHENDRADATTA PADANGSAMBIAN DENPASAR BAR...           NaN
# 721                           DENPASAR BARAT, DENPASAR           NaN
# 961  JL PADANGSAMBIAN DENPASAR DENPASAR BARAT, DENP...           1.0
#
#      kamar tidur  kamar mandi  jmlh lantai  luas bangunan  luas tanah
# 81           8.0          3.0          1.0        10000.0      1400.0
# 541          3.0          3.0          1.0         3210.0       121.0
# ...

# %%
df[df['luas bangunan'].values < 20]
# Out:
# Empty DataFrame
# Columns: [title, harga, alamat, lahan parkir, kamar tidur, kamar mandi, jmlh lantai, luas bangunan, luas tanah]
# Index: []

# %%
for x in range (0,len(df)):
  if df.iloc[x,7] < 20:
    df.iloc[x,7] = df.iloc[x,8]

# %%
df[df['luas tanah'].values < 20]
# Out:
# Empty DataFrame
# Columns: [title, harga, alamat, lahan parkir, kamar tidur, kamar mandi, jmlh lantai, luas bangunan, luas tanah]
# Index: []

# %%
df[(df['kamar tidur']>10) & ((df['kamar mandi']>10))]
# Out:
#                                                   title         harga  \
# 1089  dijual rumah 3 lantai di pura demak denpasar b...  8.500000e+09
# 1415  rumah mewah di renon denpasar,25 mtr dari jala...  2.200000e+10
# 3110       guesthouse rumah bagus kesiman denpasar bali  6.300000e+09
#
#                                                  alamat  lahan parkir  \
# 1089  JALAN PURA DEMAK, DENPASAR 80119, INDONESIA DE...           NaN
# 1415          RENON DENPASAR DENPASAR SELATAN, DENPASAR           8.0
# 3110  JALAN SOKA KESIMAN KERTALANGU KESIMAN KERTALAN...           NaN
#
#       kamar tidur  kamar mandi  jmlh lantai  luas bangunan  luas tanah
# 1089         18.0         18.0          3.0          700.0       640.0
# 1415         16.0         15.0          1.0          750.0      1400.0
# 3110         15.0         15.0          2.0          500.0       450.0

# %%
df["harga"] = df["harga"].str.replace('[','').str.replace("'",'').str.replace(']','')
df["alamat"] = df["alamat"].str.replace('[','').str.replace("'",'').str.replace(']','')
df["lahan parkir"] = df["lahan parkir"].str.replace('[','').str.replace("'",'').str.replace(']','')
df["kamar tidur"] = df["kamar tidur"].str.replace('[','').str.replace("'",'').str.replace(']','')
df["kamar mandi"] = df["kamar mandi"].str.replace('[','').str.replace("'",'').str.replace(']','')
df["jmlh lantai"] = df["jmlh lantai"].str.replace('[','').str.replace("'",'').str.replace(']','')
df["luas bangunan"] = df["luas bangunan"].str.replace('[','').str.replace("'",'').str.replace(']','')
df["luas tanah"] = df["luas tanah"].str.replace('[','').str.replace("'",'').str.replace(']','')
df["title"] = df["title"].str.replace('[','').str.replace("'",'').str.replace(']','')
df['harga'] = df['harga'].str.replace('.','').str.replace(',','')
df['harga'] = df['harga'].str.replace('Rp','')
# Out:
# <ipython-input-26-69cc1b846fd0>:1: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   df["harga"] = df["harga"].str.replace('[','').str.replace("'",'').str.replace(']','')
# <ipython-input-26-69cc1b846fd0>:2: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   df["alamat"] = df["alamat"].str.replace('[','').str.replace("'",'').str.replace(']','')
# <ipython-input-26-69cc1b846fd0>:3: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
# ...

# %%
df.duplicated().sum()
# Out:
# 192

# %%
df.shape

# %%
import numpy as np

# %%
df = df[["data-href","title","harga","alamat","lahan parkir","kamar tidur","kamar mandi","jmlh lantai","luas bangunan","luas tanah"]]

# %%
df[(df['luas bangunan'].values > df['luas tanah'].values) & (df['jmlh lantai'].values == 1)]
# Out:
# Empty DataFrame
# Columns: [data-href, title, harga, alamat, lahan parkir, kamar tidur, kamar mandi, jmlh lantai, luas bangunan, luas tanah]
# Index: []

# %%
df.iloc[1719, 7] = 2
df.iloc[1719, 4] = 4
df.iloc[1719, 8] = 200

# df.iloc[2137, 7] = 2
df.iloc[2137, 4] = 5
df.iloc[2137, 8] = 200

df.iloc[2279, 4] = 5
df.iloc[2279, 8] = 100

# %%
df[df['luas tanah'].values <= 30]
# Out:
#                                              data-href  \
# 308  https://www.lamudi.co.id/jual-rumah-di-jl-pura...
#
#                                                  title       harga  \
# 308  jual rumah di jl pura demak denpasar.kuta,tran...  1500000000
#
#                         alamat lahan parkir  kamar tidur kamar mandi  \
# 308  PEMECUTAN KELOD, DENPASAR          NaN            3           2
#
#      jmlh lantai  luas bangunan  luas tanah
# 308            1            NaN           0

# %%
df.iloc[441, 7] = 2
# df.iloc[441, 9] = 120
df.iloc[441, 9] = 120

df.iloc[2436, 7] = 1
df.iloc[2436, 4] = 10
# df.iloc[441, 9] = 120
df.iloc[2436, 9] = 300


df.iloc[2501, 9] = 200
# df.iloc[441, 9] = 120
df.iloc[2501, 4] = 4

# %%
df[df['luas bangunan'].isna() == True]
# Out:
#                                               data-href  \
# 1698  https://www.lamudi.co.id/dijual-rumah-lokasi-s...
#
#                                                   title       harga  \
# 1698  dijual rumah lokasi strategis dekat pantai di ...  6000000000
#
#                     alamat lahan parkir  kamar tidur kamar mandi  jmlh lantai  \
# 1698  SANUR KAJA, DENPASAR            2            4           2            1
#
#       luas bangunan  luas tanah
# 1698            NaN         500

# %%
for x in range(0,len(df)):
  if (df.iloc[x,9] < 300) & pd.isna(df.iloc[x,8]) :
     df.iloc[x,8] = df.iloc[x,9]

# %%
df.iloc[1677, 8] = 460
# df.iloc[441, 9] = 120
df.iloc[1677, 4] = 6

# %%
# df.iloc[1249, 8] = 300
# # df.iloc[441, 9] = 120
# df.iloc[1249, 4] = 5

df.iloc[1249, 8] = 400
# df.iloc[441, 9] = 120
df.iloc[1249, 4] = 6

# df.iloc[1839, 8] = 2400
# # df.iloc[441, 9] = 120
# df.iloc[1839, 7] = 2
# df.iloc[1839, 4] = 30

# df.iloc[2737, 8] = 350
# # df.iloc[441, 9] = 120
# df.iloc[2737, 7] = 2
# df.iloc[2737, 4] = 8

# %%
df.isna().sum()
# Out:
# data-href           0
# title               0
# harga               0
# alamat              0
# lahan parkir     1433
# kamar tidur         0
# kamar mandi         1
# jmlh lantai         0
# luas bangunan       1
# luas tanah          0
# dtype: int64

# %%
df['lahan parkir'].unique()
# Out:
# array(['2', '1', nan, '30', '3', '100', '6', '5', '4', '15', '50', 6,
#        '24', '20', '60', '10', '9', '7', '200', '14', '25', '16', 4, 30,
#        '80', 5, 10, '6600', '235', '35', 8], dtype=object)

# %%
# for x in range(0,len(df)):
#   if pd.isna(df.iloc[x,4]):
#     df.iloc[x,4] = 4
  # elif df.iloc[x,4].values < 4 :
  #   df.iloc[x,4] = 4
  # else:
  #    df.iloc[x,4] = df.iloc[x,4]

for x in range(0,len(df)):
  if df.iloc[x,4] < 4 :
    df.iloc[x,4] = 4

# %%
#mengatur data lahan parkir
for x in range(0, len(df)):
  if df.iloc[x,4] >= 4:
    if (df.iloc[x,9] - df.iloc[x,8] > 200):
       df.iloc[x,4] = 60
    elif (df.iloc[x,9] - df.iloc[x,8] <= 200) & (df.iloc[x,9] - df.iloc[x,8] >= 100):
       df.iloc[x,4] = 40
    elif (df.iloc[x,9] - df.iloc[x,8] < 100) & (df.iloc[x,9] - df.iloc[x,8] >= 80):
       df.iloc[x,4] = 30
    elif (df.iloc[x,9] - df.iloc[x,8] < 80) & (df.iloc[x,9] - df.iloc[x,8] >= 40):
       df.iloc[x,4] = 20
    elif (df.iloc[x,9] - df.iloc[x,8] < 40) & (df.iloc[x,9] - df.iloc[x,8] >= 20):
       df.iloc[x,4] = 10
    elif (df.iloc[x,9] - df.iloc[x,8] < 20) & (df.iloc[x,9] - df.iloc[x,8] >= 10):
       df.iloc[x,4] = 8
    elif (df.iloc[x,9] - df.iloc[x,8] < 10) & (df.iloc[x,9] - df.iloc[x,8] >= 8):
       df.iloc[x,4] = 6

# %%
df.dtypes
# Out:
# data-href         object
# title             object
# harga              int64
# alamat            object
# lahan parkir       int64
# kamar tidur        int64
# kamar mandi       object
# jmlh lantai        int64
# luas bangunan    float64
# luas tanah         int64
# dtype: object

# %%
df['lahan parkir'].unique()
# Out:
# array([ 4, 20,  8, 40, 30, 10, 60,  6,  5])

# %%
df[df['lahan parkir'] >= 100]
# Out:
#                                               data-href  \
# 1964  https://www.lamudi.co.id/rumah-baru-dekat-airp...
# 2510  https://www.lamudi.co.id/rumah-palapa-sidekary...
#
#                                                   title       harga  \
# 1964  rumah baru dekat airport juta dijual murah fre...  1625000000
# 2510                    rumah palapa sidekarya denpasar  2700000000
#
#                                                  alamat  lahan parkir  \
# 1964  JALAN RAYA SESETAN DENPASAR DEKAT AIRPORT SESE...           100
# 2510  SESETAN KEL., DENPASAR SELATAN, DENPASAR, INDO...           235
#
#       kamar tidur kamar mandi  jmlh lantai  luas bangunan  luas tanah
# 1964            3           3            2          135.0         100
# 2510            5           7            2          250.0         235

# %%
df.iloc[1964,4] = 5
df.iloc[2510,4] = 5

# %%
df.head(5)
# Out:
#                                            data-href  \
# 0  https://www.lamudi.co.id/rumah-murah-dijual-bu...
# 1  https://www.lamudi.co.id/jual-rumah-murah-utar...
# 2  https://www.lamudi.co.id/dijual-rumah-lantai-2...
# 3  https://www.lamudi.co.id/rumah-baru-siap-huni-...
# 4  https://www.lamudi.co.id/dijual-rumah-indent-s...
#
#                                                title       harga  \
# 0  rumah murah dijual bu di peguyangan denpasar u...  1400000000
# 1  jual rumah murah utara denpasar 400 jutaan bad...   475000000
# 2  dijual rumah lantai 2 minimalis di denpasar utara  1600000000
# 3                               rumah baru siap huni   925000000
# 4  dijual rumah indent strategis free pajak hrg 1...  1200000000
#
#                                               alamat  lahan parkir  \
# 0  JALAN RAYA PEGUYANGAN DENPASAR PEGUYANGAN KAJA...             4
# 1               PENARUNGAN PEGUYANGAN KAJA, DENPASAR             4
# ...

# %%
# # df.drop(index = 308 , inplace=True)
# df.drop(index = 1698 , inplace=True)

# %%
# df[df['kamar mandi'].isna() ==True]
df.iloc[2440,6] = 2

# %%
df.iloc[2440,0]
# Out:
# 'https://www.lamudi.co.id/rumah-mewah-view-sawah-di-lingkungan-elit-sekar-jepun-denpasar.html'

# %%
df['kamar mandi'] = df['kamar mandi'].astype(int)

# %%
df.columns
# Out:
# Index(['data-href', 'title', 'harga', 'alamat', 'lahan parkir', 'kamar tidur',
#        'kamar mandi', 'jmlh lantai', 'luas bangunan', 'luas tanah'],
#       dtype='object')

# %%
df.shape
# Out:
# (2772, 10)

# %%
df.to_csv('data_clean3.csv',index = False)

# %%
df =pd.read_csv('data_clean3.csv')
df.shape
# Out:
# (2772, 10)

# %%
list1 = []
for x in range(0,len(df)):
            #kamar tidur      #kamar mandi
  if (df.loc[x,'kamar tidur'] > 10) & (df.loc[x,'kamar mandi'] > 10):
     if(('kos' in str(df.loc[x,'title']))):
       df.drop(index =x ,inplace=True)

# %%
df.shape
# Out:
# (2743, 10)

# %%
df.dtypes
# Out:
# data-href         object
# title             object
# harga              int64
# alamat            object
# lahan parkir       int64
# kamar tidur        int64
# kamar mandi        int64
# jmlh lantai        int64
# luas bangunan    float64
# luas tanah         int64
# dtype: object

# %%
df[(df['kamar tidur'].values > 10) & (df['kamar mandi'].values > 10)]
# Out:
#                                               data-href  \
# 741   https://www.lamudi.co.id/jual-rumah-usaha-hitu...
# 1010  https://www.lamudi.co.id/rumah-villa-besar-di-...
# 1674  https://www.lamudi.co.id/dijual-rumah-luas-dan...
#
#                                                   title        harga  \
# 741   jual rumah usaha hitung tanah ex. spa @renon, ...   7500000000
# 1010  rumah villa besar di hangtuah renon hanya 200 ...  21000000000
# 1674  dijual rumah luas dan asri di tengah kota denp...  20000000000
#
#                                                alamat  lahan parkir  \
# 741                                   RENON, DENPASAR            40
# 1010  JL HANGTUAH RENON DENPASAR BALI RENON, DENPASAR            60
# 1674              JALAN HANGTUAH SANUR KAJA, DENPASAR            60
#
#       kamar tidur  kamar mandi  jmlh lantai  luas bangunan  luas tanah
# 741            16           16            1          700.0         900
# ...

# %%
df.duplicated().sum()
# Out:
# 191

# %%
df.drop_duplicates(inplace=True)

# %%
df.shape
# Out:
# (2552, 10)

# %%
df.iloc[3215]
# Out:
# title            rumah dalam kompleks perumahan kebo iwa selata...
# harga                                                 1750000000.0
# alamat                                PADANGSAMBIAN KAJA, DENPASAR
# lahan parkir                                                   1.0
# kamar tidur                                                    4.0
# kamar mandi                                                    3.0
# jmlh lantai                                                    2.0
# luas bangunan                                                170.0
# luas tanah                                                   150.0
# Name: 3215, dtype: object

# %%
#mngisi harga yang kosong
for x in range(0, len(df)):
  if pd.isna(df.iloc[x,1]):
    if (df.iloc[x,8] < 1000) & (df.iloc[x,8] > 750):
      df.iloc[x,1] =12977780000
    elif (df.iloc[x,7] <= 650) & (df.iloc[x,7] >= 400):
      df.iloc[x,1] =5814421000
    elif (df.iloc[x,7] < 400) & (df.iloc[x,7] >= 200):
      df.iloc[x,1] =4032812000
    else:
       df.iloc[x,1]=1895797000

# %%
df[df['harga'].isna() == True].sort_values('luas bangunan' , ascending =False) #980 756 = 1.297778e+10
                                                                              #700 400 = 5.814421e+09
                                                                            #400 200 = 4.032812e+09
                                                                            #300 80  = 1.895797e+09
# Out:
# Empty DataFrame
# Columns: [title, harga, alamat, lahan parkir, kamar tidur, kamar mandi, jmlh lantai, luas bangunan, luas tanah]
# Index: []

# %%
x = df[(df['harga'].isna() == False) & ((df['luas tanah'].values >= 750)& (df['luas tanah'].values <=1000)) & ((df['luas bangunan'].values >= 600)& (df['luas bangunan'].values <= 700))  & ((df['kamar tidur'].values <= 5)) & ((df['kamar tidur'].values >= 4))]
x.mean()
# Out:
# <ipython-input-43-6916318e7a07>:2: FutureWarning: The default value of numeric_only in DataFrame.mean is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   x.mean()
# harga            1.297778e+10
# lahan parkir     4.000000e+00
# kamar tidur      4.555556e+00
# kamar mandi      5.000000e+00
# jmlh lantai      1.444444e+00
# luas bangunan    6.477778e+02
# luas tanah       7.783333e+02
# dtype: float64

# %%
df[(df['harga'].isna() == False) & ((df['luas tanah'].values >= 400)& (df['luas tanah'].values <=450)) & ((df['luas bangunan'].values >= 400)& (df['luas bangunan'].values < 700))  & ((df['kamar tidur'].values <= 5)) & ((df['kamar tidur'].values >= 3))].mean()
# Out:
# <ipython-input-46-f53e6c44f096>:1: FutureWarning: The default value of numeric_only in DataFrame.mean is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df[(df['harga'].isna() == False) & ((df['luas tanah'].values >= 400)& (df['luas tanah'].values <=450)) & ((df['luas bangunan'].values >= 400)& (df['luas bangunan'].values < 700))  & ((df['kamar tidur'].values <= 5)) & ((df['kamar tidur'].values >= 3))].mean()
# harga            5.814421e+09
# lahan parkir     1.909091e+00
# kamar tidur      4.552632e+00
# kamar mandi      4.289474e+00
# jmlh lantai      1.921053e+00
# luas bangunan    5.098947e+02
# luas tanah       4.140526e+02
# dtype: float64

# %%
df[(df['harga'].isna() == False) & ((df['luas tanah'].values >= 400)& (df['luas tanah'].values <=450)) & ((df['luas bangunan'].values >= 200)& (df['luas bangunan'].values < 350))  & ((df['kamar tidur'].values <= 5)) & ((df['kamar tidur'].values >= 3))].mean()
# Out:
# <ipython-input-47-315fdc44877d>:1: FutureWarning: The default value of numeric_only in DataFrame.mean is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df[(df['harga'].isna() == False) & ((df['luas tanah'].values >= 400)& (df['luas tanah'].values <=450)) & ((df['luas bangunan'].values >= 200)& (df['luas bangunan'].values < 350))  & ((df['kamar tidur'].values <= 5)) & ((df['kamar tidur'].values >= 3))].mean()
# harga            4.032812e+09
# lahan parkir     1.620000e+01
# kamar tidur      4.500000e+00
# kamar mandi      3.531250e+00
# jmlh lantai      1.281250e+00
# luas bangunan    2.687812e+02
# luas tanah       4.104688e+02
# dtype: float64

# %%
df[(df['harga'].isna() == False) & ((df['luas tanah'].values >= 100)& (df['luas tanah'].values <=350)) & ((df['luas bangunan'].values >= 80)& (df['luas bangunan'].values < 300))  & ((df['kamar tidur'].values <= 5)) & ((df['kamar tidur'].values >= 2))].mean()
# Out:
# <ipython-input-50-32e64694031a>:1: FutureWarning: The default value of numeric_only in DataFrame.mean is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df[(df['harga'].isna() == False) & ((df['luas tanah'].values >= 100)& (df['luas tanah'].values <=350)) & ((df['luas bangunan'].values >= 80)& (df['luas bangunan'].values < 300))  & ((df['kamar tidur'].values <= 5)) & ((df['kamar tidur'].values >= 2))].mean()
# harga            1.895797e+09
# lahan parkir     4.279553e+00
# kamar tidur      3.552331e+00
# kamar mandi      2.821990e+00
# jmlh lantai      1.659848e+00
# luas bangunan    1.541879e+02
# luas tanah       1.506736e+02
# dtype: float64

# %%
df[(df['luas bangunan'].isna() == True)]
# df.iloc[2771,5] =2
# for x in range(0, len(df)):
#   if pd.isna(df.iloc[x,7]):
#     if (df.iloc[x,8] < 300) & (df.iloc[x,6] == 2):
#       df.iloc[x,7] = 150
# Out:
#                                                   title         harga  \
# 590                      rumah mewah 3.3 are buana raya  2.500000e+09
# 593             rumah 8 are di kerobokan dekat seminyak  6.000000e+09
# 1147  murah dijual rumah luas 900 m2 dijl bedugul si...  7.500000e+09
# 1460  dijual rumah murah dijl kerta husada sidakarya...  3.800000e+09
# 2799  jual rumah lantai2 style eropa clasic mix bali...  3.000000e+09
# 2883  dijual / disewakan rumah gatot subroto denpasa...  6.000000e+09
# 3842    dijual rumah pulau moyo pedungan denpasar, bali  2.000000e+09
#
#                                                 alamat  lahan parkir  \
# 590                           DENPASAR BARAT, DENPASAR           NaN
# 593                           DENPASAR BARAT, DENPASAR           NaN
# 1147  JL. BEDUGUL SIDAKARYA DENPASAR SELATAN, DENPASAR           NaN
# 1460                        DENPASAR SELATAN, DENPASAR           NaN
# ...

# %%
df.iloc[590,7] = 300
df.iloc[593,7] = 450
df.iloc[1147,7] = 600
df.iloc[1460,7] = 400
df.iloc[2799,7] = 250
df.iloc[3842,7] = 400

# %%
df[df['lahan parkir'].isna() == False]
# Out:
#                                                   title         harga  \
# 3               rumah dengan harga murah di dalung bali  8.500000e+08
# 9     rumah baru hayam wuruk denpasar 3 kamar tidur ...  1.600000e+09
# 11                    rumah akasia hayam wuruk denpasar  8.750000e+08
# 12    rumah besar 6 kamar dekat sanur dan renon denp...  3.400000e+09
# 14                       rumah modern di renon denpasar  6.000000e+09
# ...                                                 ...           ...
# 3850  rumah design modern di jln pulau moyo pedungan...  1.400000e+09
# 3851                    beli rumah dapat passive income  8.000000e+09
# 3852   rumah modern di jln pulau moyo pedungan denpasar  1.700000e+09
# 3856          dijual rumah pulau moyo pedungan denpasar  4.500000e+09
# 3857                 rumah mewah di pusat kota denpasar  1.950000e+09
#
#                                                  alamat  lahan parkir  \
# ...

# %%
df['lahan parkir'].unique()
# Out:
# array([ nan,   1.,   3.,   2.,   4., 100.,  50.,   6.,  20.,  15.,  30.,
#        500.,  60.,  25.,   5.,  10.,   9.,  21.,  12.,  11.,  40.,   8.,
#         80.,   7., 150., 120., 235.,  81.,  24.,  95., 250.,  35., 130.])

# %%
for x in range(0, len(df)):
  if df.iloc[x,3] == 1:
    df.iloc[x,3] = 4
  elif df.iloc[x,3] == 2:
    df.iloc[x,3] = 5
  elif df.iloc[x,3] == 3:
    df.iloc[x,3] = 6
  elif df.iloc[x,3] == 4:
    df.iloc[x,3] = 8

# %%
df[(df['lahan parkir'].values >= 15) & (df['lahan parkir'].values <= 40)]
# Out:
#                                                   title         harga  \
# 310   dijual cepat rumah mewah di komplek elite batu...  3.000000e+09
# 336             dijual rumah lantai 1 murah di denpasar  1.300000e+09
# 536   rumah cantik bonus tanah di padangsambian denp...  5.500000e+09
# 669   rumah style villa di gatot subroto, dekat ke b...  8.500000e+09
# 699           dijual rumah baru renovasi padang sambian  4.900000e+09
# 1150                                rumah elite merdeka  3.500000e+09
# 1402       rumah 4 kamar di kertadalem denpasar selatan  2.500000e+09
# 1699                           rumah modern tengah kota  4.500000e+09
# 1993                                   rumah style bali  2.450000e+09
# 2014                    rumah minimalis luas tanah 300m  1.500000e+09
# 2180    dijual rumah semi villa siap huni di sanur bali  5.500000e+09
# 2754                        rumah minimalis di antasura  1.800000e+09
# ...

# %%
for x in range(0, len(df)):
  if pd.isna(df.iloc[x,3]):
    if (df.iloc[x,8] - df.iloc[x,7] > 200):
       df.iloc[x,3] = 60
    elif (df.iloc[x,8] - df.iloc[x,7] <= 200) & (df.iloc[x,8] - df.iloc[x,7] >= 100):
       df.iloc[x,3] = 40
    elif (df.iloc[x,8] - df.iloc[x,7] < 100) & (df.iloc[x,8] - df.iloc[x,7] >= 80):
       df.iloc[x,3] = 30
    elif (df.iloc[x,8] - df.iloc[x,7] < 80) & (df.iloc[x,8] - df.iloc[x,7] >= 40):
       df.iloc[x,3] = 20
    elif (df.iloc[x,8] - df.iloc[x,7] < 40) & (df.iloc[x,8] - df.iloc[x,7] >= 20):
       df.iloc[x,3] = 10
    else:
       df.iloc[x,3] = 4

# %%
df.iloc[626	, 3] =5

# %%
df['lahan parkir'].unique()
# Out:
# array([10., 20.,  4.,  6.,  5.,  8., 60., 40., 30.,  7.])

# %%
df.drop(index=81 , inplace =True)

# %%
df.drop(index=88 , inplace =True)
df.drop(index=541 , inplace =True)

df.drop(index=721 , inplace =True)
df.drop(index=718 , inplace =True)

df.drop(index=961, inplace =True)
df.drop(index=2883 , inplace =True)
df.drop(index=3476 , inplace =True)

# %%
df.to_csv('data_rumah_clean3_terbaru.csv', index=False)

# %%
df.isna().sum()
# Out:
# title            0
# harga            0
# alamat           0
# lahan parkir     0
# kamar tidur      0
# kamar mandi      0
# jmlh lantai      0
# luas bangunan    0
# luas tanah       0
# dtype: int64

# %%
# df = pd.concat([df1, df2, df3])
