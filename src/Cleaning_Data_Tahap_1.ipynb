# %% [markdown]
# # Preprocesing Data Hasil Scraping Tahap 1

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# %%
# cek data kosong
df = pd.read_csv('data-scrapping-2-final.csv')
df.isna().sum()
# Out:
# data-href            0
# title                0
# harga                0
# alamat               0
# lahan parkir         0
# listrik              0
# kamar tidur          0
# kamar mandi          0
# is full furnished    0
# jmlh lantai          0
# luas bangunan        0
# luas tanah           0
# dtype: int64

# %%
df.head(5)
# Out:
#                                            data-href  \
# 0  https://www.lamudi.co.id/villa-asri-dan-natura...
# 1  https://www.lamudi.co.id/resort-mewah-dijual-m...
# 2  https://www.lamudi.co.id/villa-mewah-dijual-ce...
# 3  https://www.lamudi.co.id/resort-mewah-dijual-m...
# 4  https://www.lamudi.co.id/private-villa-dengan-...
#
#                                                title                  harga  \
# 0  ['Villa asri dan natural sekali di bali timur ...   ['Rp 5.800.000.000']
# 1  ['resort mewah dijual murah di bali timur kara...  ['Rp 10.500.000.000']
# 2  ['Villa mewah dijual cepat bawah harga pasar d...   ['Rp 4.750.000.000']
# 3  ['Resort mewah dijual murah di bali timur kara...  ['Rp 10.500.000.000']
# 4  ['PRIVATE VILLA DENGAN VIEW PADI DAN GUNUNG AG...   ['Rp 4.950.000.000']
#
#                                               alamat lahan parkir   listrik  \
# 0  ['JL RAYA SIDEMEN KARANGASEM SIDEMEN, KARANGAS...     ['null']  ['null']
# ...

# %%
df[df.duplicated()==True]
# Out:
#                                               data-href  \
# 169   https://www.lamudi.co.id/villa-australia-view-...
# 170   https://www.lamudi.co.id/jual-villa-pribadi-vi...
# 171   https://www.lamudi.co.id/murah-villa-tenang-da...
# 172   https://www.lamudi.co.id/bungalow-tengah-sawah...
# 173   https://www.lamudi.co.id/dijual-bungalow-dekat...
# ...                                                 ...
# 9242  https://www.lamudi.co.id/rumah-cluster-mahendr...
# 9364  https://www.lamudi.co.id/hot-list-dijual-rumah...
# 9365  https://www.lamudi.co.id/brand-new-minimalist-...
# 9690  https://www.lamudi.co.id/hot-list-di-jual-ruma...
# 9693  https://www.lamudi.co.id/rumah-minimalis-tukad...
#
#                                                   title                 harga  \
# 169                   ['villa Australia view mountain']    ['Rp 915.000.000']
# 170   ['Jual villa pribadi view pantai,sawah dan gun...  ['Rp 1.400.000.000']
# ...

# %%
#cek data duplikat
df.duplicated().sum() #111 baris duplicated
# Out:
# 111

# %%
#hapus data duplikat
df.drop_duplicates(inplace=True)

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df.shape
# Out:
# (10470, 12)

# %%
#cek tipe data
df.dtypes
# Out:
# data-href            object
# title                object
# harga                object
# alamat               object
# lahan parkir         object
# listrik              object
# kamar tidur          object
# kamar mandi          object
# is full furnished    object
# jmlh lantai          object
# luas bangunan        object
# luas tanah           object
# dtype: object

# %%
# membersihkan data yang dikurung dalam krangkeng
df['title'] = df['title'].str.replace('[','').str.replace(']','').str.replace("'",'')
df['harga'] = df['harga'].str.replace('[','').str.replace(']','').str.replace("'",'')
df['alamat'] = df['alamat'].str.replace('[','').str.replace(']','').str.replace("'",'')
df['lahan parkir'] = df['lahan parkir'].str.replace('[','').str.replace(']','').str.replace("'",'')
df['listrik'] = df['listrik'].str.replace('[','').str.replace(']','').str.replace("'",'')
df['kamar tidur'] = df['kamar tidur'].str.replace('[','').str.replace(']','').str.replace("'",'')
df['kamar mandi'] = df['kamar mandi'].str.replace('[','').str.replace(']','').str.replace("'",'')
df['is full furnished'] = df['is full furnished'].str.replace('[','').str.replace(']','').str.replace("'",'')
df['jmlh lantai'] = df['jmlh lantai'].str.replace('[','').str.replace(']','').str.replace("'",'')
df['luas bangunan'] = df['luas bangunan'].str.replace('[','').str.replace(']','').str.replace("'",'')
df['luas tanah'] = df['luas tanah'].str.replace('[','').str.replace(']','').str.replace("'",'')
df['harga'] = df['harga'].str.replace('Rp' , '').str.replace('.','')
# Out:
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_18264\1815674100.py:2: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   df['title'] = df['title'].str.replace('[','').str.replace(']','').str.replace("'",'')
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_18264\1815674100.py:3: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   df['harga'] = df['harga'].str.replace('[','').str.replace(']','').str.replace("'",'')
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_18264\1815674100.py:4: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
# ...

# %%
df.head()
# Out:
#                                            data-href  \
# 0  https://www.lamudi.co.id/villa-asri-dan-natura...
# 1  https://www.lamudi.co.id/resort-mewah-dijual-m...
# 2  https://www.lamudi.co.id/villa-mewah-dijual-ce...
# 3  https://www.lamudi.co.id/resort-mewah-dijual-m...
# 4  https://www.lamudi.co.id/private-villa-dengan-...
#
#                                                title         harga  \
# 0  Villa asri dan natural sekali di bali timur di...    5800000000
# 1  resort mewah dijual murah di bali timur karang...   10500000000
# 2  Villa mewah dijual cepat bawah harga pasar di ...    4750000000
# 3  Resort mewah dijual murah di bali timur karang...   10500000000
# 4    PRIVATE VILLA DENGAN VIEW PADI DAN GUNUNG AGUNG    4950000000
#
#                                               alamat lahan parkir listrik  \
# 0     JL RAYA SIDEMEN KARANGASEM SIDEMEN, KARANGASEM         null    null
# 1                            KARANG ASEM, KARANGASEM         null    null
# ...

# %%
print('title : ',len(df[df['title'] =='null']))
print('harga :', len(df[df['harga'] =='null']))
print('alamat :',len(df[df['alamat'] =='null']))
print('lahan parkir :', len(df[df['lahan parkir'] =='null']))
print('listrik :', len(df[df['listrik'] =='null']))
print('kamar tidur :',len(df[df['kamar tidur'] =='null']))
print('kamar mandi :',len(df[df['kamar mandi'] =='null']))
print('furnitur :',len(df[df['is full furnished'] =='null']))#jmlh lantai
print('jumlah lantai :',len(df[df['jmlh lantai'] =='null'])) #luas bangunan
print('luas bangunan :',len(df[df['luas bangunan'] =='null']))
print('luas tanah :',len(df[df['luas tanah'] =='null']))
# Out:
# title :  1
# harga : 45
# alamat : 1
# lahan parkir : 5584
# listrik : 10352
# kamar tidur : 21
# kamar mandi : 43
# furnitur : 10212
# jumlah lantai : 8814
# luas bangunan : 129
# luas tanah : 26

# %%
df[df.duplicated(keep=False)]
# Out:
#                                               data-href  \
# 0     https://www.lamudi.co.id/villa-asri-dan-natura...
# 4     https://www.lamudi.co.id/private-villa-dengan-...
# 14    https://www.lamudi.co.id/villa-view-laut-di-ja...
# 18    https://www.lamudi.co.id/dijual-bungalow-dekat...
# 28    https://www.lamudi.co.id/villa-australia-view-...
# ...                                                 ...
# 9365  https://www.lamudi.co.id/brand-new-minimalist-...
# 9686  https://www.lamudi.co.id/rumah-minimalis-tukad...
# 9687  https://www.lamudi.co.id/hot-list-di-jual-ruma...
# 9690  https://www.lamudi.co.id/hot-list-di-jual-ruma...
# 9693  https://www.lamudi.co.id/rumah-minimalis-tukad...
#
#                                                   title        harga  \
# 0     Villa asri dan natural sekali di bali timur di...   5800000000
# 4       PRIVATE VILLA DENGAN VIEW PADI DAN GUNUNG AGUNG   4950000000
# 14    Villa View Laut Di Jasri Karangasem Bali (DW20...   4800000000
# ...

# %%
# berdasarkan data diatas furnitur dan listrik memiliki jumlah data null terbanyak maka , data tersebut tidak akan dihapus
df2 = df[['title','alamat','lahan parkir','kamar tidur','kamar mandi','luas bangunan','luas tanah','jmlh lantai','harga']]
df2
# Out:
#                                                    title  \
# 0      Villa asri dan natural sekali di bali timur di...
# 1      resort mewah dijual murah di bali timur karang...
# 2      Villa mewah dijual cepat bawah harga pasar di ...
# 3      Resort mewah dijual murah di bali timur karang...
# 4        PRIVATE VILLA DENGAN VIEW PADI DAN GUNUNG AGUNG
# ...                                                  ...
# 10465  Dijual rumah minimalis dalam lingkungan cluste...
# 10466  Rumah Minimalis Tukad Musi Renon Raya Puputan ...
# 10467                  VILLA RIVER VIEW DI DENPASAR BALI
# 10468  RUMAH BARU 2 LANTAI JL. PALAPA SESETAN DENPASA...
# 10469  Dijual Hak Milik Rumah Gaya Bali 4 Kamar Tidur...
#
#                                                   alamat lahan parkir  \
# 0         JL RAYA SIDEMEN KARANGASEM SIDEMEN, KARANGASEM         null
# 1                                KARANG ASEM, KARANGASEM         null
# ...

# %%
df2['harga'] = df2['harga'].str.replace('Rp' , '').str.replace('.','')
# Out:
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_13936\2570471342.py:1: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   df2['harga'] = df2['harga'].str.replace('Rp' , '').str.replace('.','')
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_13936\2570471342.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2['harga'] = df2['harga'].str.replace('Rp' , '').str.replace('.','')

# %%
df2.head(5)
# Out:
#                                                title  \
# 0  Villa asri dan natural sekali di bali timur di...
# 1  resort mewah dijual murah di bali timur karang...
# 2  Villa mewah dijual cepat bawah harga pasar di ...
# 3  Resort mewah dijual murah di bali timur karang...
# 4    PRIVATE VILLA DENGAN VIEW PADI DAN GUNUNG AGUNG
#
#                                               alamat lahan parkir kamar tidur  \
# 0     JL RAYA SIDEMEN KARANGASEM SIDEMEN, KARANGASEM         null           2
# 1                            KARANG ASEM, KARANGASEM         null          11
# 2  JALAN RAYA SIDEMEN KARANGASEM BALI SIDEMEN, KA...            2           2
# 3  JALAN PANTAI JASRI KARANGASEM KARANGASEM, KARA...           10          17
# 4                                SIDEMEN, KARANGASEM         null           2
#
#   kamar mandi luas bangunan luas tanah jmlh lantai         harga
# 0           2           140       1099        null    5800000000
# ...

# %%
df2['lahan parkir'] = df2['lahan parkir'].apply(lambda x : int(x) if x != 'null' else None )
df2['kamar tidur'] = df2['kamar tidur'].apply(lambda x : int(x) if x != 'null' else None )
df2['kamar mandi'] = df2['kamar mandi'].apply(lambda x : int(x) if x != 'null' else None )
df2['luas bangunan'] = df2['luas bangunan'].apply(lambda x : float(x) if x != 'null' else None )
df2['luas tanah'] = df2['luas tanah'].apply(lambda x : float(x) if x != 'null' else None )
df2['jmlh lantai'] = df2['jmlh lantai'].apply(lambda x : int(x) if x != 'null' else None )
df2['title'] = df2['title'].apply(lambda x : str(x) if x != 'null' else None )
df2['alamat'] = df2['alamat'].apply(lambda x : str(x) if x != 'null' else None )
df2['harga'] = df2['harga'].apply(lambda x : int(x) if x != 'null' else None )
# Out:
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_18264\215641182.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2['lahan parkir'] = df2['lahan parkir'].apply(lambda x : int(x) if x != 'null' else None )
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_18264\215641182.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2['kamar tidur'] = df2['kamar tidur'].apply(lambda x : int(x) if x != 'null' else None )
# ...

# %%
df2.dtypes
# Out:
# title             object
# alamat            object
# lahan parkir     float64
# kamar tidur      float64
# kamar mandi      float64
# luas bangunan    float64
# luas tanah       float64
# jmlh lantai      float64
# harga            float64
# dtype: object

# %%
df2.isna().sum()
# Out:
# title               1
# alamat              1
# lahan parkir     5584
# kamar tidur        21
# kamar mandi        43
# luas bangunan     129
# luas tanah         26
# jmlh lantai      8814
# harga              45
# dtype: int64

# %%
# hapus data title rumah yang kosong
df2[df2['title'].isna() == True]
# Out:
#      title alamat  lahan parkir  kamar tidur  kamar mandi  luas bangunan  \
# 7758  None   None           NaN          NaN          NaN            NaN
#
#       luas tanah  jmlh lantai  harga
# 7758         NaN          NaN    NaN

# %%
df2.drop(7758, axis=0 , inplace=True)

# %%
df3 = df2

# %%
#cek data dengan value yang benar benar rumah , bukan villa atau resort
df3['title'] = df3['title'].str.lower()
df3['cek rumah'] = df3['title'].apply(lambda x : x if "rumah" in x else None )
# Out:
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_18264\330524725.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df3['title'] = df3['title'].str.lower()
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_18264\330524725.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df3['cek rumah'] = df3['title'].apply(lambda x : x if "rumah" in x else None )

# %%
bukan_rmh = df3[df3['cek rumah'].isna() == True]
rumah = df3[df3['cek rumah'].isna() == False]

# %%
rumah['kos'] = rumah['title'].apply(lambda x : x if "kos" in x else None )
# bukan_rmh['tile'].unique()
# Out:
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_18264\1551121089.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   rumah['kos'] = rumah['title'].apply(lambda x : x if "kos" in x else None )

# %%
rumah.head(5)
# Out:
#                                                 title  \
# 5   rumah minimalis murah lokasi strategis karangasem
# 6   rumah minimalis murah lokasi strategis karangasem
# 10           rumah subsidi dekat kota karangasem bali
# 12       rumah semi finishing padang kerta karangasem
# 19                        jual tanah bonus rumah lama
#
#                       alamat  lahan parkir  kamar tidur  kamar mandi  \
# 5                 KARANGASEM           NaN          2.0          1.0
# 6    KARANG ASEM, KARANGASEM           NaN          2.0          1.0
# 10   KARANG ASEM, KARANGASEM           NaN          2.0          1.0
# 12  PADANG KERTA, KARANGASEM           NaN          2.0          1.0
# 19       SUBAGAN, KARANGASEM           NaN          1.0          1.0
#
#     luas bangunan  luas tanah  jmlh lantai        harga  \
# 5            36.0       100.0          NaN  250000000.0
# 6            36.0       100.0          NaN  250000000.0
# ...

# %%
rmh = rumah[rumah['kos'].values == None]
len(rmh)
#bukan kos 4082
# Out:
# 4082

# %%
rumah[rumah['kamar tidur'].isna() == True]
# Out:
#                                    title  \
# 7069    rumah di singaraja - bali dijual
# 8019  rumah murah di pusat kota denpasar
#
#                                            alamat  lahan parkir  kamar tidur  \
# 7069                                     BULELENG           NaN          NaN
# 8019  JL RAYA TEUKU UMAR DAUH PURI KAUH, DENPASAR           NaN          NaN
#
#       kamar mandi  luas bangunan  luas tanah  jmlh lantai         harga  \
# 7069          NaN            NaN      1345.0          NaN  5.043750e+09
# 8019          NaN          520.0       520.0          NaN  4.880000e+09
#
#                                cek rumah   kos
# 7069    rumah di singaraja - bali dijual  None
# 8019  rumah murah di pusat kota denpasar  None

# %%
rumah.drop(7069 , inplace=True)
rumah.drop(8019 , inplace=True)
# Out:
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_13936\3447021182.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   rumah.drop(7069 , inplace=True)
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_13936\3447021182.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   rumah.drop(8019 , inplace=True)

# %%
rumah[rumah['kamar mandi'].isna() == True]
# Out:
#                                                   title  \
# 8379            rumah 4 kamar tidur lokasi di sidakarya
# 8410  rumah 3 kamar tidur lokasi sangat strategis di...
#
#                                                  alamat  lahan parkir  \
# 8379             SIDAKARYA DENPASAR SIDAKARYA, DENPASAR           NaN
# 8410  GATSU BARAT DENPASAR BARAT GATOT SUBROTO, DENP...           NaN
#
#       kamar tidur  kamar mandi  luas bangunan  luas tanah  jmlh lantai  \
# 8379          4.0          NaN          140.0       100.0          NaN
# 8410          3.0          NaN          175.0       148.0          NaN
#
#              harga                                          cek rumah   kos
# 8379  1.100000e+09            rumah 4 kamar tidur lokasi di sidakarya  None
# 8410  2.200000e+09  rumah 3 kamar tidur lokasi sangat strategis di...  None

# %%
rumah['kamar mandi'].fillna(2, inplace=True)
# Out:
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_13936\1241563916.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   rumah['kamar mandi'].fillna(2, inplace=True)

# %%
rumah.dtypes
# Out:
# title             object
# alamat            object
# lahan parkir     float64
# kamar tidur      float64
# kamar mandi      float64
# luas bangunan    float64
# luas tanah       float64
# jmlh lantai      float64
# harga            float64
# tile              object
# cek rumah         object
# kos               object
# dtype: object

# %%
rumah.isna().sum()
# Out:
# title               0
# alamat              0
# lahan parkir     2497
# kamar tidur         0
# kamar mandi         0
# luas bangunan      38
# luas tanah          9
# jmlh lantai      3619
# harga              11
# cek rumah           0
# kos              4080
# dtype: int64

# %%
x = rumah[rumah['luas bangunan'].isna() == False]
y = rumah[rumah['luas bangunan'].isna() == True]
#rumah.loc[(rumah["luas bangunan"].isna() == True) & (rumah["luas tanah"] <= 50) , 'luas bangunan'] = 47
rumah.loc[(rumah["luas bangunan"].isna() == True) & (rumah["luas tanah"] >= 50) & (rumah["luas tanah"] <= 100) , 'luas bangunan'] = 70
rumah.loc[(rumah["luas bangunan"].isna() == True) & (rumah["luas tanah"] > 100) & (rumah["luas tanah"] <= 150) , 'luas bangunan'] = 145
rumah.loc[(rumah["luas bangunan"].isna() == True) & (rumah["luas tanah"] > 150) & (rumah["luas tanah"] <= 200) , 'luas bangunan'] = 172
rumah.loc[(rumah["luas bangunan"].isna() == True) & (rumah["luas tanah"] > 200) & (rumah["luas tanah"] <= 250) , 'luas bangunan'] = 233
rumah.loc[(rumah["luas bangunan"].isna() == True) & (rumah["luas tanah"] > 250) & (rumah["luas tanah"] <= 300) , 'luas bangunan'] = 279
rumah.loc[(rumah["luas bangunan"].isna() == True) & (rumah["luas tanah"] > 450) & (rumah["luas tanah"] <= 500) , 'luas bangunan'] = 470
rumah.loc[(rumah["luas bangunan"].isna() == True) & (rumah["luas tanah"] >= 900) & (rumah["luas tanah"] <= 950) , 'luas bangunan'] = 870
rumah.loc[(rumah["luas bangunan"].isna() == True) & (rumah["luas tanah"] > 1000) & (rumah["luas tanah"] <= 1301) , 'luas bangunan'] = 1000
rumah.loc[(rumah["luas bangunan"].isna() == True) & (rumah["luas tanah"] > 2700) & (rumah["luas tanah"] <= 2800) , 'luas bangunan'] = 2500

# %%
rumah.loc[(rumah["luas bangunan"].isna() == True) & (rumah["luas tanah"] > 350) & (rumah["luas tanah"] <= 400) , 'luas bangunan'] = 350

# %%
#x[(x['luas tanah'].values == 150) & (x['jmlh lantai'].values == 1) &(x['luas bangunan'].values < 151) ].mean() # 150
#x[(x['luas tanah'].values < 50) & (x['jmlh lantai'].values == 1) & (x['luas bangunan'].values < 51) ].mean() # 47
#x[(x['luas tanah'].values > 51) & (x['luas tanah'].values < 100) & (x['jmlh lantai'].values == 1) & (x['luas bangunan'].values > 51)  & (x['luas bangunan'].values < 100)].mean() #70
#x[(x['luas tanah'].values > 151) & (x['luas tanah'].values < 200) & (x['jmlh lantai'].values == 1) & (x['luas bangunan'].values > 151)  & (x['luas bangunan'].values < 200)].mean() #172
#x[(x['luas tanah'].values > 200) & (x['luas tanah'].values < 250) & (x['jmlh lantai'].values == 1) & (x['luas bangunan'].values > 200)  & (x['luas bangunan'].values < 250)].mean() #233
#x[(x['luas tanah'].values >= 250) & (x['luas tanah'].values <= 300) & (x['jmlh lantai'].values == 1) & (x['luas bangunan'].values >= 250)  & (x['luas bangunan'].values <= 300)].mean() #279
#x[(x['luas tanah'].values > 450) & (x['luas tanah'].values < 500) & (x['jmlh lantai'].values == 1) & (x['luas bangunan'].values >= 450)  & (x['luas bangunan'].values < 500)].mean() #470
#x[(x['luas tanah'].values >= 450) & (x['luas tanah'].values <= 500) & (x['jmlh lantai'].values == 1) & (x['luas bangunan'].values >= 451)  & (x['luas bangunan'].values <= 500)].mean() #490
#x[(x['luas tanah'].values >=850 ) & (x['luas tanah'].values > 905) & (x['jmlh lantai'].values == 1) & (x['luas bangunan'].values >= 850)  & (x['luas bangunan'].values <= 905)].mean() #910

# %%
new_rumah = rumah[(rumah['luas tanah'].values < rumah['luas bangunan'].values) & (rumah['jmlh lantai'].values < 2) ]
new_rumah['lantai2'] = new_rumah['title'].apply(lambda x : 2 if ('2lt' in x or 'lt2' in x or 'lt' in x  or  '2 lantai' in x or 'lantai' in x or '2 lt' in x) else None)
new_rumah['lantai3'] = new_rumah['title'].apply(lambda x : 3 if ('3lt' in x or 'lt3' in x ) else None)
# Out:
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_17688\2272834823.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_rumah['lantai2'] = new_rumah['title'].apply(lambda x : 2 if ('2lt' in x or 'lt2' in x or 'lt' in x  or  '2 lantai' in x or 'lantai' in x or '2 lt' in x) else None)
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_17688\2272834823.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# ...

# %%
x = new_rumah[new_rumah['lantai1'].isna() == True]

# %%
x =new_rumah[new_rumah['lantai'].isna() == True]
x
#pd.set_option('display.max_colwidth', 200)
#x['title']
# for y in x['title']:
#     print(y)
# pd.set_option('display.max_colwidth', 200)
# print(new_rumah['lantai'])
# Out:
#                                                              title  \
# 239     perumahan japanese tropical style with ricefield view ubud
# 267    dijual cepat rumah tinggal view bandara dan tol di jimbaran
# 289                               rumah villa di ubud full furnish
# 304           dijual cepat rumah kost termurah dekat denpasar bali
# 307                                 rumah cluster terbesar di ubud
# ...                                                            ...
# 10415                    rumah murah di area denpasar selatan bali
# 10419                    rumah baru 3 kamar tidur dijual hak milik
# 10422           jual rumah denpasar pura demak denpasar barat bali
# 10425  hot list dijual rumah kos an di gelogor carik denpasar bali
# 10429               dijual rumah semi villa di merta ayu-kerobokan
#
#                                                        alamat  lahan parkir  \
# 239                                             UBUD, GIANYAR           NaN
# ...

# %%
rumah.isna().sum()
# Out:
# title               0
# alamat              0
# lahan parkir     2497
# kamar tidur         0
# kamar mandi         0
# luas bangunan       2
# luas tanah          9
# jmlh lantai         0
# harga              11
# tile                0
# cek rumah           0
# kos              4080
# dtype: int64

# %%
rumah.to_csv('clean_rumah1.csv',index=False)

# %%
df7 = pd.read_csv('clean_rumah1.csv')
df7.shape
# Out:
# (4195, 12)

# %%
df6 = df5

# %%
df6
# Out:
#                                                                       title  \
# 0                         rumah minimalis murah lokasi strategis karangasem
# 1                         rumah minimalis murah lokasi strategis karangasem
# 2                                  rumah subsidi dekat kota karangasem bali
# 3                              rumah semi finishing padang kerta karangasem
# 4                                               jual tanah bonus rumah lama
# ...                                                                     ...
# 4190            hot list di jual rumah gress baru lokasi nusa indah pemogan
# 4191  dijual rumah minimalis dalam lingkungan cluster di sesetan - denpasar
# 4192    rumah minimalis tukad musi renon raya puputan tukad unda batanghari
# 4193           rumah baru 2 lantai jl. palapa sesetan denpasar selatan bali
# 4194           dijual hak milik rumah gaya bali 4 kamar tidur di sanur area
#
# ...

# %%
for x in range(0,len(df6)):
    if df6.iloc[x,7] == 1:
        if  (('second' in str(df6.iloc[x,0])) and  ('lt' in str(df6.iloc[x,0]))) or (('lantai' in str(df6.iloc[x,0])) and ('2' in str(df6.iloc[x,0]))) or (('lantai' in str(df6.iloc[x,0])) and ('dua' in str(df6.iloc[x,0]))) or (('lt' in str(df6.iloc[x,0])) and ('2' in str(df6.iloc[x,0]))) or (('lt' in str(df6.iloc[x,0])) and ('dua' in str(df6.iloc[x,0]))):
            #(('second' in str(df6.iloc[x,0])) &  ('lt' in str(df6.iloc[x,0]))) or (('lantai' in str(df6.iloc[x,0])) and ('2' in str(df6.iloc[x,0]))) or (('lantai' in str(df6.iloc[x,0])) and ('dua' in str(df6.iloc[x,0]))) or (('lt' in str(df6.iloc[x,0])) and ('2' in str(df6.iloc[x,0]))) or (('lt' in str(df6.iloc[x,0])) and ('dua' in str(df6.iloc[x,0]))):
            df6.loc[x,'jmlh lantai'] = 2
        elif (('three' in str(df6.iloc[x,0])) and  ('lt' in str(df6.iloc[x,0]))) or (('lantai' in str(df6.iloc[x,0])) and ('3' in str(df6.iloc[x,0]))) or (('lantai' in str(df6.iloc[x,0])) and ('tiga' in str(df6.iloc[x,0]))) or (('lt' in str(df6.iloc[x,0])) and ('3' in str(df6.iloc[x,0]))) or (('lt' in str(df6.iloc[x,0])) and ('tiga' in str(df6.iloc[x,0]))):
            df6.loc[x,'jmlh lantai'] = 3
        else:
            df6.loc[x,'jmlh lantai'] = 1
    else:
        df6.loc[x,'jmlh lantai'] =  df6.iloc[x,7]

# %%
for x in range(0,len(df6)):
    if df6.iloc[x,7] ==1:
        print(df6.iloc[x,0])
# Out:
# rumah minimalis murah lokasi strategis karangasem
# rumah minimalis murah lokasi strategis karangasem
# rumah subsidi dekat kota karangasem bali
# rumah semi finishing padang kerta karangasem
# jual tanah bonus rumah lama
# rumah strategis dekat kawasan pariwisata padang bai
# dijual rumah di desa
# rumah classic murah jogja. ndalem hinggil mewah eksklusif
# rumah style villa plus pool di karangasem - bali
# dijual cepat rumah murah minimalis daerah karangasem
# dijual 2 unit rumah style joglo view laut sawah dan gunung
# angsuran 2 jutaan rumah minimalis di padang kerta karangasem bali
# jual cepat rumah murah di desa padang kerta karangasem bali
# dijual rumah testing location check - karangasem
# dijual rumah testing location check - karang asem
# dijual rumah testing location check - manggis
# dijual rumah testing location check - abang
# dijual rumah testing location check - rendang
# dijual rumah testing location check - kubu
# ...

# %%
df6.head(10)
# Out:
#                                                                 title  \
# 0                   rumah minimalis murah lokasi strategis karangasem
# 1                   rumah minimalis murah lokasi strategis karangasem
# 2                            rumah subsidi dekat kota karangasem bali
# 3                        rumah semi finishing padang kerta karangasem
# 4                                         jual tanah bonus rumah lama
# 5                 rumah strategis dekat kawasan pariwisata padang bai
# 6                                                dijual rumah di desa
# 7           rumah classic murah jogja. ndalem hinggil mewah eksklusif
# 8                    rumah style villa plus pool di karangasem - bali
# 9  dijual buc rumah 2 lantai di lingkungan komplek di bali karangasem
#
#                                          alamat  lahan parkir  kamar tidur  \
# 0                                    KARANGASEM           NaN          2.0
# ...

# %%
y = df6[(df6['luas bangunan'].values > df6['luas tanah'].values) & (df6['jmlh lantai'].values == 1 ) ]

# %%
y  = df6[df6['luas tanah'].isna() == True]
y
# Out:
#                                                                                                                                                                                                         title  \
# 164                                                                                                               dijual cepat rumah baru siap huni model minimalis type 100/75 lokasi batubulan gianyar bali
# 1227                                                                                                                                             jual bangunan rumah kayu knockdown 5x10m model a-frame house
# 1322                                                                                                                                                                 rumah asri view sawah 20 mnt dari canggu
# ...

# %%
df6.loc[(df6["luas tanah"].isna() == True) & (df6["luas bangunan"] == 50) , 'luas tanah'] = 63
df6.loc[(df6["luas tanah"].isna() == True) & (df6["luas bangunan"] == 60) , 'luas tanah'] = 70
df6.loc[(df6["luas tanah"].isna() == True) & (df6["luas bangunan"] == 75) , 'luas tanah'] = 85
df6.loc[(df6["luas tanah"].isna() == True) & (df6["luas bangunan"] == 60) , 'luas tanah'] = 70
df6.loc[(df6["luas tanah"].isna() == True) & (df6["luas bangunan"] == 89) , 'luas tanah'] = 99
df6.loc[(df6["luas tanah"].isna() == True) & (df6["luas bangunan"] == 41) , 'luas tanah'] = 51
df6.loc[(df6["luas tanah"].isna() == True) & (df6["luas bangunan"] == 90) , 'luas tanah'] = 100
df6.loc[(df6["luas tanah"].isna() == True) & (df6["luas bangunan"] == 150) , 'luas tanah'] = 160
# df6.loc[(rumah["luas tanah"].isna() == True) & (df6["luas bangunan"] == 41)] = 44

# %%
df6.loc[1322]
# Out:
# title                   rumah asri view sawah 20 mnt dari canggu
# alamat           LESTARI NYITDAH RESIDENCE NO 12 KEDIRI, TABANAN
# lahan parkir                                                 NaN
# kamar tidur                                                  1.0
# kamar mandi                                                  1.0
# luas bangunan                                               41.0
# luas tanah                                                  44.0
# jmlh lantai                                                  1.0
# harga                                                580000000.0
# tile                    rumah asri view sawah 20 mnt dari canggu
# cek rumah               rumah asri view sawah 20 mnt dari canggu
# kos                                                          NaN
# Name: 1322, dtype: object

# %%
df6.loc[1322]
# Out:
# title                   rumah asri view sawah 20 mnt dari canggu
# alamat           LESTARI NYITDAH RESIDENCE NO 12 KEDIRI, TABANAN
# lahan parkir                                                 NaN
# kamar tidur                                                  1.0
# kamar mandi                                                  1.0
# luas bangunan                                               41.0
# luas tanah                                                   NaN
# jmlh lantai                                                  1.0
# harga                                                580000000.0
# tile                    rumah asri view sawah 20 mnt dari canggu
# cek rumah               rumah asri view sawah 20 mnt dari canggu
# kos                                                          NaN
# Name: 1322, dtype: object

# %%
y  = df6[df6['luas bangunan'].isna() == True]
y
# Out:
#                                                   title  \
# 1407  wow murah banget ‼️ rumah dekat canggu cuma 250jt
# 1912                         rumah super murah jembrana
#
#                             alamat  lahan parkir  kamar tidur  kamar mandi  \
# 1407               KEDIRI, TABANAN           NaN          2.0          1.0
# 1912  TEGAL BADENG TIMUR, JEMBRANA           NaN          2.0          1.0
#
#       luas bangunan  luas tanah  jmlh lantai        harga  \
# 1407            NaN        30.0          1.0  250000000.0
# 1912            NaN        36.0          1.0  165000000.0
#
#                                                    tile  \
# 1407  wow murah banget ‼️ rumah dekat canggu cuma 250jt
# 1912                         rumah super murah jembrana
#
#                                               cek rumah  kos
# 1407  wow murah banget ‼️ rumah dekat canggu cuma 250jt  NaN
# 1912                         rumah super murah jembrana  NaN

# %%
df6.loc[(df6["luas bangunan"].isna() == True) & (df6["luas tanah"] == 30) , "luas bangunan"] = 30
df6.loc[(df6["luas bangunan"].isna() == True) & (df6["luas tanah"] == 36) , "luas bangunan"] = 36

# %%
y  = df6[df6['harga'].isna() == True]
y[y['luas tanah']< 300] # 2m
y[(y['luas tanah']> 300) & (y['luas tanah']< 900)] #6.3 m
y # 3.5 m
# Out:
#                                                                        title  \
# 214                         rumah gianyar abianbase 200m2 land 3 kamar tidur
# 241         rumah modern style villa dekat baypass ida bagus mantra, gianyar
# 1068  dijual cepat rumah pribadi di taman griya 3 km tidur furniture lengkap
# 1206                          rumah abianbase badung 2 kamar tidur siap huni
# 2352                   rumah denpasar jl buluh indah 3 kamar tidur siap huni
# 2736                     rumah mewah modern minimalis gatsu barat link elite
# 2888                       rumah 3 kamar tidur sanur view sawah dekat pantai
# 3124                   rumah mewah gatsu tengah 980m2 land with private pool
# 3564                     rumah ayani denpasar minimalis modern 4 kamar tidur
# 3575          rumah cantik dan luas area tukad badung, renon denpasar - bali
# 4125                     rumah modern siap huni hanya 150 mtr dari jln utama
#
# ...

# %%
df6.loc[(df6["harga"].isna() == True) & (df6["luas tanah"] < 300) , "harga" ] = 2000000000
df6.loc[(df6["harga"].isna() == True) & ((df6["luas tanah"] > 300) & (df6["luas tanah"] < 600)) , "harga"] = 6300000000
df6.loc[(df6["harga"].isna() == True) & (df6["luas tanah"] == 980 ) , "harga"] = 400000000

# %%
df6[((df6['luas tanah'] > 800) & (df6['luas tanah'] < 1000)) & ((df6['luas bangunan'] > 600) & (df6['luas bangunan'] < 700))]
# Out:
#                                                       title  \
# 2299            rumah shm di denpasar renon bali (bvdps890)
# 3124  rumah mewah gatsu tengah 980m2 land with private pool
#
#                         alamat  lahan parkir  kamar tidur  kamar mandi  \
# 2299           RENON, DENPASAR           NaN          7.0          6.0
# 3124  DENPASAR UTARA, DENPASAR           NaN          5.0          5.0
#
#       luas bangunan  luas tanah  jmlh lantai         harga  \
# 2299          627.0       890.0          1.0  1.700000e+10
# 3124          688.0       980.0          1.0           NaN
#
#                                                        tile  \
# 2299            rumah shm di denpasar renon bali (bvdps890)
# 3124  rumah mewah gatsu tengah 980m2 land with private pool
#
#                                                   cek rumah  kos
# 2299            rumah shm di denpasar renon bali (bvdps890)  NaN
# 3124  rumah mewah gatsu tengah 980m2 land with private pool  NaN

# %%
df6.loc[3124]
# Out:
# title            rumah mewah gatsu tengah 980m2 land with private pool
# alamat                                        DENPASAR UTARA, DENPASAR
# lahan parkir                                                       NaN
# kamar tidur                                                        5.0
# kamar mandi                                                        5.0
# luas bangunan                                                    688.0
# luas tanah                                                       980.0
# jmlh lantai                                                        1.0
# harga                                                      400000000.0
# tile             rumah mewah gatsu tengah 980m2 land with private pool
# cek rumah        rumah mewah gatsu tengah 980m2 land with private pool
# kos                                                                NaN
# Name: 3124, dtype: object

# %%
for x in range(0,len(y)):
    print(y.iloc[x,0])
# Out:
# rumah gianyar abianbase 200m2 land 3 kamar tidur
# rumah modern style villa dekat baypass ida bagus mantra, gianyar
# dijual cepat rumah pribadi di taman griya 3 km tidur furniture lengkap
# rumah abianbase badung 2 kamar tidur siap huni
# rumah denpasar jl buluh indah 3 kamar tidur siap huni
# rumah mewah modern minimalis gatsu barat link elite
# rumah 3 kamar tidur sanur view sawah dekat pantai
# rumah mewah gatsu tengah 980m2 land with private pool
# rumah ayani denpasar minimalis modern 4 kamar tidur
# rumah cantik dan luas area tukad badung, renon denpasar - bali
# rumah modern siap huni hanya 150 mtr dari jln utama

# %%
for x in range(0, len(df6)):
  if pd.isna(df6.iloc[x,3]):
    if (df6.iloc[x,8] - df6.iloc[x,7] > 200):
       df6.iloc[x,3] = 60
    elif (df6.iloc[x,8] - df6.iloc[x,7] <= 200) & (df6.iloc[x,8] - df6.iloc[x,7] >= 100):
       df6.iloc[x,3] = 40
    elif (df6.iloc[x,8] - df6.iloc[x,7] < 100) & (df6.iloc[x,8] - df6.iloc[x,7] >= 80):
       df6.iloc[x,3] = 30
    elif (df6.iloc[x,8] - df6.iloc[x,7] < 80) & (df6.iloc[x,8] - df6.iloc[x,7] >= 40):
       df6.iloc[x,3] = 20
    elif (df6.iloc[x,8] - df6.iloc[x,7] < 40) & (df6.iloc[x,8] - df6.iloc[x,7] >= 20):
       df6.iloc[x,3] = 10
    else:
       df6.iloc[x,3] = 4
# Out:
#                                                                      title  \
# 419                 rumah semi villa siap huni harga miring d gianyar bali
# 420                     rumah mewah siap huni tepi jalan di pering gianyar
# 1376                                              rumah bonus tanah murmer
# 2279                rumah mewah 9 kamar tidur lokasi strategis di denpasar
# 2339  rumah manis di lokasi sangat strategis berada di pusat kota denpasar
#
#                                                               alamat  \
# 419                                               BLAHBATUH, GIANYAR
# 420                                               BLAHBATUH, GIANYAR
# 1376                                              SELEMADEG, TABANAN
# 2279                                   JALAN NUSA KAMBANGAN DENPASAR
# 2339  JALAN TEUKU UMAR, DENPASAR, INDONESIA DENPASAR BARAT, DENPASAR
#
#       lahan parkir  kamar tidur  kamar mandi  luas bangunan  luas tanah  \
# ...

# %%
df6.loc[df6['luas bangunan'].values == 1 , 'luas bangunan'] =100
#df6.loc[710 , 'luas tanah' ]= 100

# %%
df6['kamar tidur'].unique()
# Out:
# array([ 2.,  1.,  3.,  4.,  9.,  6.,  5.,  8., 10.,  7., 12., 14., 11.,
#        20., 34., 15., 17., 16., 22., 28., 13., 43.])

# %%
df6.loc[1018 , 'luas bangunan' ] = 30
df6.loc[2097 , 'luas bangunan' ] = 100
df6.loc[2347 , 'luas bangunan' ] = 50
df6.loc[3940 , 'luas bangunan' ] = 20

# %%
df6.loc[716 , 'luas tanah' ] = 120
df6.loc[1178 , 'luas tanah' ] = 200
df6.loc[1844 , 'luas tanah' ] = 130
df6.loc[1872 , 'luas tanah' ] = 150

# %%
df6.isna().sum()
# Out:
# title               0
# alamat              0
# lahan parkir        0
# kamar tidur         0
# kamar mandi         0
# luas bangunan       0
# luas tanah          0
# jmlh lantai         0
# harga               0
# tile                0
# cek rumah           0
# kos              4080
# dtype: int64

# %%
df6.to_csv('data clean rumah1')

# %%
import pandas as pd

# %%
df = pd.read_csv('data rumah clean.csv')

# %%
df.shape
# Out:
# (7199, 9)

# %%
df.head(5)
# Out:
#                                                title      harga  \
# 0            rumah murah lokasi strategis karangasem  250000000
# 1  rumah minimalis murah lokasi strategis karangasem  250000000
# 2           rumah subsidi dekat kota karangasem bali  178000000
# 3       rumah semi finishing padang kerta karangasem  250000000
# 4  rumah classic murah jogja. ndalem hinggil mewa...  509000000
#
#                                          alamat  parkir motor  kamar tidur  \
# 0                                    KARANGASEM            20            2
# 1                       KARANG ASEM, KARANGASEM            20            2
# 2                       KARANG ASEM, KARANGASEM            10            2
# 3                      PADANG KERTA, KARANGASEM            20            2
# 4  KARANGASEM, INDONESIA KARANGASEM, KARANGASEM            10            3
#
#    kamar mandi  jmlh lantai  luas bangunan  luas tanah
# 0            1            1           36.0         100
# ...

# %%
kab = ['badung','bangli','buleleng','gianyar','jembrana','karangasem','klungkung','tabanan','denpasar']

# %%
df['alamat'] = df['alamat'].str.lower()

# %%
for x in kab:
    print(x)
# Out:
# badung
# bangli
# buleleng
# gianyar
# jembrana
# karangasem
# klungkung
# tabanan

# %%
import numpy as np

# %%
def kab(alamat):
    kab = ['badung','bangli','buleleng','gianyar','jembrana','karangasem','klungkung','tabanan','denpasar']
    for x in kab:
        if x in alamat:
            return x
    return np.nan

# %%
def tes(alamat):
    #kab = ['badung','bangli','buleleng','gianyar','jembrana','karangasem','klungkung','tabanan','denpasar']
    #for x in kab:
    if 'klungkung' in alamat:
        return 'klungkung'
    else:
        return None

#     return np.nan

# %%
alamat = 'kab , jln baru raya denpasar karangasem'
data(alamat)
# Out:
# karangasem

# %%
c = df['alamat'].apply(lambda x : tes(x) )

# %%
df['kabupaten'].unique()
# Out:
# array(['karangasem', 'gianyar', 'badung', 'tabanan', 'buleleng',
#        'jembrana', 'bangli', 'denpasar'], dtype=object)

# %%
c = set(c)
print(c)
# Out:
# {None}

# %%
x = df.groupby('kabupaten')['kabupaten'].count()

# %%
x
# Out:
# kabupaten
# badung         742
# bangli           2
# buleleng        61
# denpasar      5688
# gianyar        340
# jembrana        11
# karangasem      11
# tabanan        344
# Name: kabupaten, dtype: int64

# %%
x.values
# Out:
# array([ 742,    2,   61, 5688,  340,   11,   11,  344], dtype=int64)

# %%
import matplotlib.pyplot as plt
fig = plt.figure(figsize=(15,5))
ax = fig.add_subplot(111)
ax.bar(x.index, x.values)
ax.set_title('Jumlah Data Rumah Tiap Kabupaten')
ax.set_xlabel('Kabupaten')
ax.set_ylabel('Jumlah')
ax.legend()
plt.show()
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %%
df.head(5)
# Out:
#                                                title      harga  \
# 0            rumah murah lokasi strategis karangasem  250000000
# 1  rumah minimalis murah lokasi strategis karangasem  250000000
# 2           rumah subsidi dekat kota karangasem bali  178000000
# 3       rumah semi finishing padang kerta karangasem  250000000
# 4  rumah classic murah jogja. ndalem hinggil mewa...  509000000
#
#                                          alamat  parkir motor  kamar tidur  \
# 0                                    karangasem            20            2
# 1                       karang asem, karangasem            20            2
# 2                       karang asem, karangasem            10            2
# 3                      padang kerta, karangasem            20            2
# 4  karangasem, indonesia karangasem, karangasem            10            3
#
#    kamar mandi  jmlh lantai  luas bangunan  luas tanah   kabupaten
# ...

# %%
df.to_csv('data harga rumah clean baru.csv', index=False)

# %% [markdown]
# # Eksplorasi Data Analisis
